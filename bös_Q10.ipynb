# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import math
import scipy.stats
import numpy as np
from scipy.stats import truncnorm
from scipy.stats import multivariate_normal
from matplotlib import cbook, cm
from matplotlib.colors import LightSource
from scipy.stats import norm

# %%
N = 10_000
s_1 = np.zeros(N)
s_2 = np.zeros(N)
sig_t = 5
A = np.array([[1, -1]])
t = np.zeros(N)
sigma_s = np.array([[100, 0], [0, 100]]) 
mu_matrix = np.array([100, 100]) 

s_1[0] = 100
s_2[0] = 100
t[0] = 20

# %%
def gibbs_sample(N, burn, mu_s1, var_s1, mu_s2, var_s2, y):

    # N total iterations
    # [N - burn] values are returned

    s_1 = np.zeros(N)
    s_2 = np.zeros(N)
    t = np.zeros(N)

    sigma_s = np.array([[var_s1, 0], [0, var_s2]]) 

    # print(f"sigma_s: {sigma_s}\n")

    mu_matrix = np.array([[mu_s1], [mu_s2]]) 

    # print(f"mu matrix: {mu_matrix}\n")

    s_1[0] = np.random.normal(mu_s1, np.sqrt(var_s1))
    s_2[0] = np.random.normal(mu_s2, np.sqrt(var_s2))
    
    mu_t = mu_s1 - mu_s2 # to calc mu_t before game with anterior skills
    sig_t = var_s1 + var_s2

    y = y

    # do heavy calculations before loop
    A = np.array([[1, -1]])
    sigma_st = np.linalg.inv(np.linalg.inv(sigma_s) + A.transpose()*(sig_t**(-1))*A)
    sig_s__mu_mat = np.matmul(np.linalg.inv(sigma_s),mu_matrix)
    A_t__sig_t = A.transpose()*(sig_t**(-1))
  
    for n in range(N-1):
        #print(s_1[:n+1])
        mu_t = s_1[n] - s_2[n] #calc mu_t with posterior skills
        a, b = (-mu_t)/np.sqrt(sig_t), np.inf


        if(y == 1):
            t[n+1] = truncnorm.rvs(a, b, loc= mu_t, scale = np.sqrt(sig_t), size=1)
        else:
            t[n+1] = truncnorm.rvs(-b, a, loc= mu_t, scale = np.sqrt(sig_t), size=1)



        mu_st = np.matmul(sigma_st,(sig_s__mu_mat + A_t__sig_t*t[n+1]))
        # print(mu_st,"\n")
        new_s = np.random.multivariate_normal([mu_st[0][0], mu_st[1][0]], sigma_st)
        s_1[n+1] = new_s[0]
        s_2[n+1] = new_s[1]

    return(s_1[burn:], s_2[burn:], t[burn:])

# %%
def gibbs_sample_v2(N, mu_s1, sig_s1, mu_s2, sig_s2, y):

    s1_samps = []
    s2_samps = []
    t_samps = []

    sig_s = np.array([[sig_s1, 0],
                      [0, sig_s2]])
    
    mu_s = np.array([mu_s1, mu_s2])

    mu_t = mu_s1 - mu_s2
    sig_t = sig_s1 + sig_s1

    A = np.array([1, -1])
    a, b = 0, np.inf

    for n in range(N):
        t_samps.append(truncnorm.rvs(a, b, loc=mu_t, scale=np.sqrt(sig_t), size=1))
        sig_st = np.linalg.inv(np.linalg.inv(sig_s) + A.transpose()*(1/sig_t)*A)
        print(sig_st)
        mu_st = np.matmul(sig_st, (np.matmul(np.linalg.inv(sig_s), mu_s) + A.transpose()*(1/sig_t)*t[n]))
        print(mu_st)
        s_samp = np.random.multivariate_normal([mu_st[0], mu_st[1]], sig_st)

        s1_samps.append(s_samp[0])
        s2_samps.append(s_samp[1])

    return(s1_samps, s2_samps)

# %%
iter = 10000
burn = 2000
s1, s2, t = gibbs_sample(iter, 0, 25, 25/3, 25, 25/3, 1)

# Sassuolo vs Empoli -> Sassuolo won
# 2
# Sassuolo: [33.51 -> 38.56] & [3.75 -> 2.97]
# Empoli: [20.11 -> 34.07] & [4.49 -> 3.34]

# %%
iterations_num = [i + 1 for i in range(iter-0)]

plt.rcParams['figure.figsize'] = [10, 10]
fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(iterations_num,s1)
axs[0, 0].set_title("s1 samples")
axs[0, 1].hist(s1,bins = "auto")
axs[0, 1].set_title("s1 dist")
axs[1, 0].plot(iterations_num,s2)
axs[1, 0].set_title("s2 samples")
axs[1, 1].hist(s2,bins = "auto")
axs[1, 1].set_title("s2 dist")
# axs[2, 0].plot(iterations_num,t)
# axs[2, 0].set_title("t samples")
# axs[2, 1].hist(t,bins = "auto")
# axs[2, 1].set_title("t dist")
plt.show()

print(f"mean_s1 = {np.mean(s1)}, var_s1 = {np.var(s1)}")
print(f"mean_s2 = {np.mean(s2)}, var_s2 = {np.var(s2)}")



# plt.plot(iterations_num,s1[burnin:])
# plt.show()
# plt.hist(s1[burnin:],bins = "auto")
# plt.show()
# plt.plot(iterations_num,s2[burnin:])
# plt.show()
# plt.hist(s2[burnin:],bins = "auto")
# plt.show()
# plt.plot(iterations_num,t[burnin:])
# plt.show()
# plt.hist(t[burnin:],bins = "auto")
# plt.show()
# Out:
# mean_s1 = 26.13018144258194, var_s1 = 7.157426176964597
# mean_s2 = 23.871379669104975, var_s2 = 7.064519341437647

# %%
iter = 1000
burn = 200
s1, s2, t = gibbs_sample(iter, burn, 25, 25/3, 25, 25/3, 1)

mu, std = norm.fit(s1)

plt.hist(s1, bins = 25, density=True, alpha = 0.6, color = "b")
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth= 2)

title = f"{iter} samples"
plt.title(title)

plt.show()

# %%
# READ DATA FILE
data = pd.read_csv("SerieA.csv", delimiter=",")
print(data)
# Out:
#      yyyy-mm-dd  HH:MM       team1     team2  score1  score2
# 0    2018-08-18  18:00      Chievo  Juventus       2       3
# 1    2018-08-18  20:30       Lazio    Napoli       1       2
# 2    2018-08-19  18:00      Torino      Roma       0       1
# 3    2018-08-19  20:30    Sassuolo     Inter       1       0
# 4    2018-08-19  20:30       Parma   Udinese       2       2
# ..          ...    ...         ...       ...     ...     ...
# 375  2019-05-26  20:30        Roma     Parma       2       1
# 376  2019-05-26  20:30       Inter    Empoli       2       1
# 377  2019-05-26  20:30  Fiorentina     Genoa       0       0
# 378  2019-05-26  20:30    Cagliari   Udinese       1       2
# 379  2019-05-26  20:30    Atalanta  Sassuolo       3       1
#
# [380 rows x 6 columns]

# %%
# MODIFY DATA

#all teams in serie a
teams = data["team1"].unique()

#initial skill, Microsoft sets new players as mu = 25 and sigma = 25/3
init_s = 25
init_var = 25/3

#assign skill and var
team_skills = {}
for team in teams:
    #team_skills = {teamname : [mean, var]}
    team_skills[team] = [init_s, init_var]

# %%
# GIBBS SAMPLE EVERY MATCH

for index, match in data.iterrows():
    # identify teams
    team1 = match['team1']
    team2 = match['team2']
    print(f"{round(100*(index+1)/380,2)}%---------------------------------------------")

    #ignore draws
    if(match["score1"] == match["score2"]):
        print("Draw")
        continue

    # find current team values
    mu_s1, mu_s2 = team_skills[team1][0], team_skills[team2][0]
    var_s1, var_s2 = team_skills[team1][1], team_skills[team2][1]

    #number of iterations in gibbs sampling
    iter = 1000

    #check what team won
    if(match["score1"] > match["score2"]):
        y = 1
        print(f"{team1} vs {team2} -> {team1} won")
    else:
        y = -1
        print(f"{team1} vs {team2} -> {team2} won")

    # call sample func
    s1, s2, t = gibbs_sample(2500, 500, mu_s1, var_s1, mu_s2, var_s2, y)

    

    #calc new mean and var
    new_mu_s1 = np.mean(s1)
    new_mu_s2 = np.mean(s2)
    
    # 
    new_var_s1 = np.var(s1)
    new_var_s2 = np.var(s2)

    print(f"{team1}: [{round(mu_s1,2)} -> {round(new_mu_s1,2)}] & [{round(var_s1,2)} -> {round(new_var_s1,2)}]") 
    print(f"{team2}: [{round(mu_s2,2)} -> {round(new_mu_s2,2)}] & [{round(var_s2,2)} -> {round(new_var_s2,2)}]")


    team_skills[team1] = [new_mu_s1, new_var_s1]
    team_skills[team2] = [new_mu_s2, new_var_s2]
# Out:
# 0.26%---------------------------------------------
# Chievo vs Juventus -> Juventus won
# Chievo: [25 -> 23.85] & [8.33 -> 7.14]
# Juventus: [25 -> 26.09] & [8.33 -> 7.51]
# 0.53%---------------------------------------------
# Lazio vs Napoli -> Napoli won
# Lazio: [25 -> 23.86] & [8.33 -> 6.92]
# Napoli: [25 -> 26.15] & [8.33 -> 7.25]
# 0.79%---------------------------------------------
# Torino vs Roma -> Roma won
# Torino: [25 -> 23.88] & [8.33 -> 6.98]
# Roma: [25 -> 26.23] & [8.33 -> 6.88]
# 1.05%---------------------------------------------
# Sassuolo vs Inter -> Sassuolo won
# Sassuolo: [25 -> 26.11] & [8.33 -> 6.67]
# Inter: [25 -> 23.84] & [8.33 -> 6.93]
# 1.32%---------------------------------------------
# Draw
# 1.58%---------------------------------------------
# Empoli vs Cagliari -> Empoli won
# Empoli: [25 -> 26.18] & [8.33 -> 7.1]
# Cagliari: [25 -> 23.91] & [8.33 -> 6.94]
# 1.84%---------------------------------------------
# Bologna vs Spal -> Spal won
# Bologna: [25 -> 23.68] & [8.33 -> 7.33]
# Spal: [25 -> 26.1] & [8.33 -> 6.81]
# 2.11%---------------------------------------------
# Atalanta vs Frosinone -> Atalanta won
# Atalanta: [25 -> 26.09] & [8.33 -> 6.75]
# Frosinone: [25 -> 24.0] & [8.33 -> 7.02]
# 2.37%---------------------------------------------
# Juventus vs Lazio -> Juventus won
# Juventus: [26.09 -> 26.88] & [7.51 -> 6.75]
# Lazio: [23.86 -> 23.21] & [6.92 -> 6.15]
# 2.63%---------------------------------------------
# Napoli vs Milan -> Napoli won
# Napoli: [26.15 -> 26.93] & [7.25 -> 6.22]
# Milan: [25 -> 24.05] & [8.33 -> 6.7]
# 2.89%---------------------------------------------
# Spal vs Parma -> Spal won
# Spal: [26.1 -> 26.88] & [6.81 -> 6.19]
# Parma: [25 -> 23.97] & [8.33 -> 6.5]
# 3.16%---------------------------------------------
# Udinese vs Sampdoria -> Udinese won
# Udinese: [25 -> 26.09] & [8.33 -> 7.16]
# Sampdoria: [25 -> 23.9] & [8.33 -> 6.71]
# 3.42%---------------------------------------------
# Draw
# 3.68%---------------------------------------------
# Genoa vs Empoli -> Genoa won
# Genoa: [25 -> 26.47] & [8.33 -> 6.64]
# Empoli: [26.18 -> 24.96] & [7.1 -> 6.1]
# 3.95%---------------------------------------------
# Draw
# 4.21%---------------------------------------------
# Fiorentina vs Chievo -> Fiorentina won
# Fiorentina: [25 -> 26.03] & [8.33 -> 7.13]
# Chievo: [23.85 -> 22.92] & [7.14 -> 5.93]
# 4.47%---------------------------------------------
# Draw
# 4.74%---------------------------------------------
# Draw
# 5.0%---------------------------------------------
# Milan vs Roma -> Milan won
# Milan: [24.05 -> 25.39] & [6.7 -> 5.33]
# Roma: [26.23 -> 24.85] & [6.88 -> 5.9]
# 5.26%---------------------------------------------
# Bologna vs Inter -> Inter won
# Bologna: [23.68 -> 22.64] & [7.33 -> 6.06]
# Inter: [23.84 -> 24.87] & [6.93 -> 5.75]
# 5.53%---------------------------------------------
# Parma vs Juventus -> Juventus won
# Parma: [23.97 -> 23.49] & [6.5 -> 5.76]
# Juventus: [26.88 -> 27.47] & [6.75 -> 5.89]
# 5.79%---------------------------------------------
# Fiorentina vs Udinese -> Fiorentina won
# Fiorentina: [26.03 -> 27.25] & [7.13 -> 6.15]
# Udinese: [26.09 -> 24.99] & [7.16 -> 6.08]
# 6.05%---------------------------------------------
# Torino vs Spal -> Torino won
# Torino: [23.88 -> 25.56] & [6.98 -> 5.7]
# Spal: [26.88 -> 25.44] & [6.19 -> 5.03]
# 6.32%---------------------------------------------
# Sassuolo vs Genoa -> Sassuolo won
# Sassuolo: [26.11 -> 27.12] & [6.67 -> 5.51]
# Genoa: [26.47 -> 25.36] & [6.64 -> 5.54]
# 6.58%---------------------------------------------
# Sampdoria vs Napoli -> Sampdoria won
# Sampdoria: [23.9 -> 25.54] & [6.71 -> 5.34]
# Napoli: [26.93 -> 25.52] & [6.22 -> 5.08]
# 6.84%---------------------------------------------
# Lazio vs Frosinone -> Lazio won
# Lazio: [23.21 -> 24.34] & [6.15 -> 4.82]
# Frosinone: [24.0 -> 22.82] & [7.02 -> 5.52]
# 7.11%---------------------------------------------
# Draw
# 7.37%---------------------------------------------
# Atalanta vs Cagliari -> Cagliari won
# Atalanta: [26.09 -> 24.74] & [6.75 -> 5.6]
# Cagliari: [23.91 -> 25.33] & [6.94 -> 5.45]
# 7.63%---------------------------------------------
# Inter vs Parma -> Parma won
# Inter: [24.87 -> 23.55] & [5.75 -> 4.75]
# Parma: [23.49 -> 24.65] & [5.76 -> 4.86]
# 7.89%---------------------------------------------
# Napoli vs Fiorentina -> Napoli won
# Napoli: [25.52 -> 26.59] & [5.08 -> 4.16]
# Fiorentina: [27.25 -> 26.0] & [6.15 -> 4.7]
# 8.16%---------------------------------------------
# Frosinone vs Sampdoria -> Sampdoria won
# Frosinone: [22.82 -> 22.24] & [5.52 -> 5.06]
# Sampdoria: [25.54 -> 26.1] & [5.34 -> 4.79]
# 8.42%---------------------------------------------
# Draw
# 8.68%---------------------------------------------
# Draw
# 8.95%---------------------------------------------
# Juventus vs Sassuolo -> Juventus won
# Juventus: [27.47 -> 28.45] & [5.89 -> 5.06]
# Sassuolo: [27.12 -> 26.28] & [5.51 -> 4.65]
# 9.21%---------------------------------------------
# Genoa vs Bologna -> Genoa won
# Genoa: [25.36 -> 25.99] & [5.54 -> 5.09]
# Bologna: [22.64 -> 21.93] & [6.06 -> 5.13]
# 9.47%---------------------------------------------
# Empoli vs Lazio -> Lazio won
# Empoli: [24.96 -> 23.92] & [6.1 -> 4.75]
# Lazio: [24.34 -> 25.26] & [4.82 -> 4.0]
# 9.74%---------------------------------------------
# Draw
# 10.0%---------------------------------------------
# Spal vs Atalanta -> Spal won
# Spal: [25.44 -> 26.17] & [5.03 -> 4.42]
# Atalanta: [24.74 -> 23.93] & [5.6 -> 4.58]
# 10.26%---------------------------------------------
# Draw
# 10.53%---------------------------------------------
# Sassuolo vs Empoli -> Sassuolo won
# Sassuolo: [26.28 -> 26.8] & [4.65 -> 4.17]
# Empoli: [23.92 -> 23.35] & [4.75 -> 4.22]
# 10.79%---------------------------------------------
# Parma vs Cagliari -> Parma won
# Parma: [24.65 -> 25.51] & [4.86 -> 3.94]
# Cagliari: [25.33 -> 24.25] & [5.45 -> 4.37]
# 11.05%---------------------------------------------
# Fiorentina vs Spal -> Fiorentina won
# Fiorentina: [26.0 -> 26.87] & [4.7 -> 4.06]
# Spal: [26.17 -> 25.24] & [4.42 -> 3.78]
# 11.32%---------------------------------------------
# Sampdoria vs Inter -> Inter won
# Sampdoria: [26.1 -> 24.78] & [4.79 -> 3.91]
# Inter: [23.55 -> 24.83] & [4.75 -> 3.85]
# 11.58%---------------------------------------------
# Torino vs Napoli -> Napoli won
# Torino: [25.56 -> 24.74] & [5.7 -> 4.84]
# Napoli: [26.59 -> 27.13] & [4.16 -> 3.78]
# 11.84%---------------------------------------------
# Lazio vs Genoa -> Lazio won
# Lazio: [25.26 -> 26.15] & [4.0 -> 3.58]
# Genoa: [25.99 -> 24.83] & [5.09 -> 4.12]
# 12.11%---------------------------------------------
# Chievo vs Udinese -> Udinese won
# Chievo: [22.92 -> 22.29] & [5.93 -> 5.28]
# Udinese: [24.99 -> 25.62] & [6.08 -> 5.22]
# 12.37%---------------------------------------------
# Bologna vs Roma -> Bologna won
# Bologna: [21.93 -> 23.29] & [5.13 -> 4.36]
# Roma: [24.85 -> 23.39] & [5.9 -> 4.79]
# 12.63%---------------------------------------------
# Draw
# 12.89%---------------------------------------------
# Frosinone vs Juventus -> Juventus won
# Frosinone: [22.24 -> 22.07] & [5.06 -> 4.91]
# Juventus: [28.45 -> 28.74] & [5.06 -> 4.66]
# 13.16%---------------------------------------------
# Inter vs Fiorentina -> Inter won
# Inter: [24.83 -> 25.96] & [3.85 -> 3.19]
# Fiorentina: [26.87 -> 25.71] & [4.06 -> 3.08]
# 13.42%---------------------------------------------
# Udinese vs Lazio -> Lazio won
# Udinese: [25.62 -> 24.73] & [5.22 -> 4.49]
# Lazio: [26.15 -> 26.83] & [3.58 -> 3.23]
# 13.68%---------------------------------------------
# Roma vs Frosinone -> Roma won
# Roma: [23.39 -> 24.14] & [4.79 -> 3.79]
# Frosinone: [22.07 -> 21.3] & [4.91 -> 4.38]
# 13.95%---------------------------------------------
# Napoli vs Parma -> Napoli won
# Napoli: [27.13 -> 27.66] & [3.78 -> 3.15]
# Parma: [25.51 -> 25.01] & [3.94 -> 3.5]
# 14.21%---------------------------------------------
# Juventus vs Bologna -> Juventus won
# Juventus: [28.74 -> 28.96] & [4.66 -> 4.26]
# Bologna: [23.29 -> 23.04] & [4.36 -> 3.97]
# 14.47%---------------------------------------------
# Genoa vs Chievo -> Genoa won
# Genoa: [24.83 -> 25.21] & [4.12 -> 3.67]
# Chievo: [22.29 -> 21.79] & [5.28 -> 4.51]
# 14.74%---------------------------------------------
# Draw
# 15.0%---------------------------------------------
# Draw
# 15.26%---------------------------------------------
# Spal vs Sassuolo -> Sassuolo won
# Spal: [25.24 -> 24.72] & [3.78 -> 3.25]
# Sassuolo: [26.8 -> 27.43] & [4.17 -> 3.74]
# 15.53%---------------------------------------------
# Draw
# 15.79%---------------------------------------------
# Roma vs Lazio -> Roma won
# Roma: [24.14 -> 25.47] & [3.79 -> 2.96]
# Lazio: [26.83 -> 25.68] & [3.23 -> 2.64]
# 16.05%---------------------------------------------
# Juventus vs Napoli -> Juventus won
# Juventus: [28.96 -> 29.57] & [4.26 -> 3.65]
# Napoli: [27.66 -> 27.17] & [3.15 -> 2.69]
# 16.32%---------------------------------------------
# Inter vs Cagliari -> Inter won
# Inter: [25.96 -> 26.44] & [3.19 -> 2.83]
# Cagliari: [24.25 -> 23.56] & [4.37 -> 3.73]
# 16.58%---------------------------------------------
# Bologna vs Udinese -> Bologna won
# Bologna: [23.04 -> 24.09] & [3.97 -> 3.23]
# Udinese: [24.73 -> 23.53] & [4.49 -> 3.43]
# 16.84%---------------------------------------------
# Frosinone vs Genoa -> Genoa won
# Frosinone: [21.3 -> 20.93] & [4.38 -> 3.92]
# Genoa: [25.21 -> 25.47] & [3.67 -> 3.39]
# 17.11%---------------------------------------------
# Fiorentina vs Atalanta -> Fiorentina won
# Fiorentina: [25.71 -> 26.16] & [3.08 -> 2.74]
# Atalanta: [23.93 -> 23.31] & [4.58 -> 3.74]
# 17.37%---------------------------------------------
# Chievo vs Torino -> Torino won
# Chievo: [21.79 -> 21.33] & [4.51 -> 3.85]
# Torino: [24.74 -> 25.23] & [4.84 -> 4.24]
# 17.63%---------------------------------------------
# Parma vs Empoli -> Parma won
# Parma: [25.01 -> 25.48] & [3.5 -> 3.17]
# Empoli: [23.35 -> 22.81] & [4.22 -> 3.81]
# 17.89%---------------------------------------------
# Sassuolo vs Milan -> Milan won
# Sassuolo: [27.43 -> 26.44] & [3.74 -> 3.21]
# Milan: [25.39 -> 26.81] & [5.33 -> 4.23]
# 18.16%---------------------------------------------
# Sampdoria vs Spal -> Sampdoria won
# Sampdoria: [24.78 -> 25.67] & [3.91 -> 3.34]
# Spal: [24.72 -> 24.03] & [3.25 -> 2.87]
# 18.42%---------------------------------------------
# Torino vs Frosinone -> Torino won
# Torino: [25.23 -> 25.52] & [4.24 -> 3.86]
# Frosinone: [20.93 -> 20.69] & [3.92 -> 3.58]
# 18.68%---------------------------------------------
# Cagliari vs Bologna -> Cagliari won
# Cagliari: [23.56 -> 24.46] & [3.73 -> 2.94]
# Bologna: [24.09 -> 23.37] & [3.23 -> 2.7]
# 18.95%---------------------------------------------
# Udinese vs Juventus -> Juventus won
# Udinese: [23.53 -> 23.47] & [3.43 -> 3.19]
# Juventus: [29.57 -> 29.68] & [3.65 -> 3.46]
# 19.21%---------------------------------------------
# Empoli vs Roma -> Roma won
# Empoli: [22.81 -> 22.37] & [3.81 -> 3.34]
# Roma: [25.47 -> 25.89] & [2.96 -> 2.64]
# 19.47%---------------------------------------------
# Genoa vs Parma -> Parma won
# Genoa: [25.47 -> 24.78] & [3.39 -> 2.82]
# Parma: [25.48 -> 26.12] & [3.17 -> 2.64]
# 19.74%---------------------------------------------
# Milan vs Chievo -> Milan won
# Milan: [26.81 -> 27.0] & [4.23 -> 4.2]
# Chievo: [21.33 -> 21.11] & [3.85 -> 3.7]
# 20.0%---------------------------------------------
# Lazio vs Fiorentina -> Lazio won
# Lazio: [25.68 -> 26.4] & [2.64 -> 2.18]
# Fiorentina: [26.16 -> 25.42] & [2.74 -> 2.29]
# 20.26%---------------------------------------------
# Atalanta vs Sampdoria -> Sampdoria won
# Atalanta: [23.31 -> 22.85] & [3.74 -> 3.39]
# Sampdoria: [25.67 -> 26.1] & [3.34 -> 3.04]
# 20.53%---------------------------------------------
# Napoli vs Sassuolo -> Napoli won
# Napoli: [27.17 -> 27.72] & [2.69 -> 2.29]
# Sassuolo: [26.44 -> 25.85] & [3.21 -> 2.54]
# 20.79%---------------------------------------------
# Spal vs Inter -> Inter won
# Spal: [24.03 -> 23.72] & [2.87 -> 2.53]
# Inter: [26.44 -> 26.76] & [2.83 -> 2.42]
# 21.05%---------------------------------------------
# Roma vs Spal -> Spal won
# Roma: [25.89 -> 24.85] & [2.64 -> 2.07]
# Spal: [23.72 -> 24.74] & [2.53 -> 2.08]
# 21.32%---------------------------------------------
# Draw
# 21.58%---------------------------------------------
# Udinese vs Napoli -> Napoli won
# Udinese: [23.47 -> 23.27] & [3.19 -> 3.0]
# Napoli: [27.72 -> 27.84] & [2.29 -> 2.08]
# 21.84%---------------------------------------------
# Draw
# 22.11%---------------------------------------------
# Parma vs Lazio -> Lazio won
# Parma: [26.12 -> 25.5] & [2.64 -> 2.23]
# Lazio: [26.4 -> 26.91] & [2.18 -> 1.8]
# 22.37%---------------------------------------------
# Chievo vs Atalanta -> Atalanta won
# Chievo: [21.11 -> 20.56] & [3.7 -> 3.09]
# Atalanta: [22.85 -> 23.27] & [3.39 -> 2.99]
# 22.63%---------------------------------------------
# Draw
# 22.89%---------------------------------------------
# Draw
# 23.16%---------------------------------------------
# Inter vs Milan -> Inter won
# Inter: [26.76 -> 27.3] & [2.42 -> 2.03]
# Milan: [27.0 -> 26.01] & [4.2 -> 3.28]
# 23.42%---------------------------------------------
# Draw
# 23.68%---------------------------------------------
# Atalanta vs Parma -> Atalanta won
# Atalanta: [23.27 -> 24.37] & [2.99 -> 2.31]
# Parma: [25.5 -> 24.61] & [2.23 -> 1.83]
# 23.95%---------------------------------------------
# Empoli vs Juventus -> Juventus won
# Empoli: [22.37 -> 22.24] & [3.34 -> 3.11]
# Juventus: [29.68 -> 29.71] & [3.46 -> 3.31]
# 24.21%---------------------------------------------
# Draw
# 24.47%---------------------------------------------
# Draw
# 24.74%---------------------------------------------
# Spal vs Frosinone -> Frosinone won
# Spal: [24.74 -> 23.7] & [2.08 -> 1.76]
# Frosinone: [20.69 -> 22.53] & [3.58 -> 2.62]
# 25.0%---------------------------------------------
# Draw
# 25.26%---------------------------------------------
# Cagliari vs Chievo -> Cagliari won
# Cagliari: [24.46 -> 24.72] & [2.94 -> 2.73]
# Chievo: [20.56 -> 20.27] & [3.09 -> 3.02]
# 25.53%---------------------------------------------
# Milan vs Sampdoria -> Milan won
# Milan: [26.01 -> 26.77] & [3.28 -> 2.83]
# Sampdoria: [26.1 -> 25.38] & [3.04 -> 2.47]
# 25.79%---------------------------------------------
# Draw
# 26.05%---------------------------------------------
# Lazio vs Inter -> Inter won
# Lazio: [26.91 -> 26.45] & [1.8 -> 1.57]
# Inter: [27.3 -> 27.85] & [2.03 -> 1.65]
# 26.32%---------------------------------------------
# Milan vs Genoa -> Milan won
# Milan: [26.77 -> 27.2] & [2.83 -> 2.58]
# Genoa: [24.78 -> 24.44] & [2.82 -> 2.48]
# 26.58%---------------------------------------------
# Napoli vs Empoli -> Napoli won
# Napoli: [27.84 -> 27.87] & [2.08 -> 1.99]
# Empoli: [22.24 -> 22.29] & [3.11 -> 2.85]
# 26.84%---------------------------------------------
# Inter vs Genoa -> Inter won
# Inter: [27.85 -> 27.99] & [1.65 -> 1.61]
# Genoa: [24.44 -> 24.15] & [2.48 -> 2.2]
# 27.11%---------------------------------------------
# Draw
# 27.37%---------------------------------------------
# Juventus vs Cagliari -> Juventus won
# Juventus: [29.71 -> 29.82] & [3.31 -> 3.13]
# Cagliari: [24.72 -> 24.64] & [2.73 -> 2.57]
# 27.63%---------------------------------------------
# Lazio vs Spal -> Lazio won
# Lazio: [26.45 -> 26.66] & [1.57 -> 1.38]
# Spal: [23.7 -> 23.5] & [1.76 -> 1.69]
# 27.89%---------------------------------------------
# Sampdoria vs Torino -> Torino won
# Sampdoria: [25.38 -> 24.78] & [2.47 -> 2.21]
# Torino: [25.52 -> 26.35] & [3.86 -> 3.11]
# 28.16%---------------------------------------------
# Draw
# 28.42%---------------------------------------------
# Chievo vs Sassuolo -> Sassuolo won
# Chievo: [20.27 -> 20.22] & [3.02 -> 2.96]
# Sassuolo: [25.85 -> 25.91] & [2.54 -> 2.47]
# 28.68%---------------------------------------------
# Bologna vs Atalanta -> Atalanta won
# Bologna: [23.37 -> 22.89] & [2.7 -> 2.31]
# Atalanta: [24.37 -> 24.78] & [2.31 -> 2.01]
# 28.95%---------------------------------------------
# Udinese vs Milan -> Milan won
# Udinese: [23.27 -> 23.13] & [3.0 -> 2.75]
# Milan: [27.2 -> 27.36] & [2.58 -> 2.42]
# 29.21%---------------------------------------------
# Draw
# 29.47%---------------------------------------------
# Torino vs Parma -> Parma won
# Torino: [26.35 -> 25.2] & [3.11 -> 2.43]
# Parma: [24.61 -> 25.3] & [1.83 -> 1.54]
# 29.74%---------------------------------------------
# Draw
# 30.0%---------------------------------------------
# Genoa vs Napoli -> Napoli won
# Genoa: [24.15 -> 24.01] & [2.2 -> 2.11]
# Napoli: [27.87 -> 28.02] & [1.99 -> 1.79]
# 30.26%---------------------------------------------
# Atalanta vs Inter -> Atalanta won
# Atalanta: [24.78 -> 26.08] & [2.01 -> 1.71]
# Inter: [27.99 -> 26.98] & [1.61 -> 1.3]
# 30.53%---------------------------------------------
# Roma vs Sampdoria -> Roma won
# Roma: [24.85 -> 25.45] & [2.07 -> 1.78]
# Sampdoria: [24.78 -> 24.17] & [2.21 -> 1.85]
# 30.79%---------------------------------------------
# Empoli vs Udinese -> Empoli won
# Empoli: [22.29 -> 23.14] & [2.85 -> 2.46]
# Udinese: [23.13 -> 22.36] & [2.75 -> 2.38]
# 31.05%---------------------------------------------
# Draw
# 31.32%---------------------------------------------
# Draw
# 31.58%---------------------------------------------
# Milan vs Juventus -> Juventus won
# Milan: [27.36 -> 27.0] & [2.42 -> 2.2]
# Juventus: [29.82 -> 30.26] & [3.13 -> 2.86]
# 31.84%---------------------------------------------
# Udinese vs Roma -> Udinese won
# Udinese: [22.36 -> 23.68] & [2.38 -> 1.85]
# Roma: [25.45 -> 24.49] & [1.78 -> 1.5]
# 32.11%---------------------------------------------
# Juventus vs Spal -> Juventus won
# Juventus: [30.26 -> 30.29] & [2.86 -> 2.73]
# Spal: [23.5 -> 23.47] & [1.69 -> 1.7]
# 32.37%---------------------------------------------
# Inter vs Frosinone -> Inter won
# Inter: [26.98 -> 27.02] & [1.3 -> 1.27]
# Frosinone: [22.53 -> 22.42] & [2.62 -> 2.41]
# 32.63%---------------------------------------------
# Parma vs Sassuolo -> Parma won
# Parma: [25.3 -> 25.79] & [1.54 -> 1.38]
# Sassuolo: [25.91 -> 25.16] & [2.47 -> 1.96]
# 32.89%---------------------------------------------
# Draw
# 33.16%---------------------------------------------
# Empoli vs Atalanta -> Empoli won
# Empoli: [23.14 -> 24.43] & [2.46 -> 1.83]
# Atalanta: [26.08 -> 25.2] & [1.71 -> 1.46]
# 33.42%---------------------------------------------
# Draw
# 33.68%---------------------------------------------
# Draw
# 33.95%---------------------------------------------
# Draw
# 34.21%---------------------------------------------
# Draw
# 34.47%---------------------------------------------
# Draw
# 34.74%---------------------------------------------
# Fiorentina vs Juventus -> Juventus won
# Fiorentina: [25.42 -> 25.25] & [2.29 -> 2.23]
# Juventus: [30.29 -> 30.53] & [2.73 -> 2.55]
# 35.0%---------------------------------------------
# Sampdoria vs Bologna -> Sampdoria won
# Sampdoria: [24.17 -> 24.48] & [1.85 -> 1.61]
# Bologna: [22.89 -> 22.42] & [2.31 -> 2.02]
# 35.26%---------------------------------------------
# Milan vs Parma -> Milan won
# Milan: [27.0 -> 27.45] & [2.2 -> 1.71]
# Parma: [25.79 -> 25.57] & [1.38 -> 1.28]
# 35.53%---------------------------------------------
# Torino vs Genoa -> Torino won
# Torino: [25.2 -> 25.7] & [2.43 -> 2.1]
# Genoa: [24.01 -> 23.6] & [2.11 -> 1.87]
# 35.79%---------------------------------------------
# Draw
# 36.05%---------------------------------------------
# Draw
# 36.32%---------------------------------------------
# Draw
# 36.58%---------------------------------------------
# Draw
# 36.84%---------------------------------------------
# Atalanta vs Napoli -> Napoli won
# Atalanta: [25.2 -> 25.08] & [1.46 -> 1.36]
# Napoli: [28.02 -> 28.14] & [1.79 -> 1.64]
# 37.11%---------------------------------------------
# Juventus vs Inter -> Juventus won
# Juventus: [30.53 -> 30.71] & [2.55 -> 2.37]
# Inter: [27.02 -> 26.92] & [1.27 -> 1.18]
# 37.37%---------------------------------------------
# Napoli vs Frosinone -> Napoli won
# Napoli: [28.14 -> 28.17] & [1.64 -> 1.64]
# Frosinone: [22.42 -> 22.33] & [2.41 -> 2.38]
# 37.63%---------------------------------------------
# Draw
# 37.89%---------------------------------------------
# Draw
# 38.16%---------------------------------------------
# Draw
# 38.42%---------------------------------------------
# Udinese vs Atalanta -> Atalanta won
# Udinese: [23.68 -> 23.33] & [1.85 -> 1.5]
# Atalanta: [25.08 -> 25.32] & [1.36 -> 1.23]
# 38.68%---------------------------------------------
# Draw
# 38.95%---------------------------------------------
# Empoli vs Bologna -> Empoli won
# Empoli: [24.43 -> 24.69] & [1.83 -> 1.57]
# Bologna: [22.42 -> 22.09] & [2.02 -> 1.78]
# 39.21%---------------------------------------------
# Draw
# 39.47%---------------------------------------------
# Draw
# 39.74%---------------------------------------------
# Inter vs Udinese -> Inter won
# Inter: [26.92 -> 26.96] & [1.18 -> 1.13]
# Udinese: [23.33 -> 23.24] & [1.5 -> 1.4]
# 40.0%---------------------------------------------
# Torino vs Juventus -> Juventus won
# Torino: [25.7 -> 25.63] & [2.1 -> 1.96]
# Juventus: [30.71 -> 30.81] & [2.37 -> 2.26]
# 40.26%---------------------------------------------
# Draw
# 40.53%---------------------------------------------
# Sampdoria vs Parma -> Sampdoria won
# Sampdoria: [24.48 -> 25.19] & [1.61 -> 1.27]
# Parma: [25.57 -> 24.98] & [1.28 -> 1.08]
# 40.79%---------------------------------------------
# Frosinone vs Sassuolo -> Sassuolo won
# Frosinone: [22.33 -> 22.06] & [2.38 -> 2.23]
# Sassuolo: [25.16 -> 25.42] & [1.96 -> 1.83]
# 41.05%---------------------------------------------
# Fiorentina vs Empoli -> Fiorentina won
# Fiorentina: [25.25 -> 25.85] & [2.23 -> 1.81]
# Empoli: [24.69 -> 24.32] & [1.57 -> 1.38]
# 41.32%---------------------------------------------
# Cagliari vs Napoli -> Napoli won
# Cagliari: [24.64 -> 24.55] & [2.57 -> 2.32]
# Napoli: [28.17 -> 28.31] & [1.64 -> 1.55]
# 41.58%---------------------------------------------
# Roma vs Genoa -> Roma won
# Roma: [24.49 -> 24.89] & [1.5 -> 1.31]
# Genoa: [23.6 -> 23.17] & [1.87 -> 1.61]
# 41.84%---------------------------------------------
# Atalanta vs Lazio -> Atalanta won
# Atalanta: [25.32 -> 25.97] & [1.23 -> 0.99]
# Lazio: [26.66 -> 25.93] & [1.38 -> 1.1]
# 42.11%---------------------------------------------
# Draw
# 42.37%---------------------------------------------
# Lazio vs Cagliari -> Lazio won
# Lazio: [25.93 -> 26.07] & [1.1 -> 1.01]
# Cagliari: [24.55 -> 24.13] & [2.32 -> 1.94]
# 42.63%---------------------------------------------
# Draw
# 42.89%---------------------------------------------
# Draw
# 43.16%---------------------------------------------
# Napoli vs Spal -> Napoli won
# Napoli: [28.31 -> 28.4] & [1.55 -> 1.45]
# Spal: [23.47 -> 23.38] & [1.7 -> 1.6]
# 43.42%---------------------------------------------
# Milan vs Fiorentina -> Fiorentina won
# Milan: [27.45 -> 26.71] & [1.71 -> 1.46]
# Fiorentina: [25.85 -> 26.65] & [1.81 -> 1.4]
# 43.68%---------------------------------------------
# Genoa vs Atalanta -> Genoa won
# Genoa: [23.17 -> 24.4] & [1.61 -> 1.12]
# Atalanta: [25.97 -> 25.24] & [0.99 -> 0.83]
# 43.95%---------------------------------------------
# Empoli vs Sampdoria -> Sampdoria won
# Empoli: [24.32 -> 23.92] & [1.38 -> 1.21]
# Sampdoria: [25.19 -> 25.55] & [1.27 -> 1.09]
# 44.21%---------------------------------------------
# Draw
# 44.47%---------------------------------------------
# Draw
# 44.74%---------------------------------------------
# Juventus vs Roma -> Juventus won
# Juventus: [30.81 -> 30.85] & [2.26 -> 2.25]
# Roma: [24.89 -> 24.82] & [1.31 -> 1.23]
# 45.0%---------------------------------------------
# Draw
# 45.26%---------------------------------------------
# Sampdoria vs Chievo -> Sampdoria won
# Sampdoria: [25.55 -> 25.55] & [1.09 -> 1.11]
# Chievo: [20.22 -> 20.11] & [2.96 -> 2.96]
# 45.53%---------------------------------------------
# Fiorentina vs Parma -> Parma won
# Fiorentina: [26.65 -> 25.81] & [1.4 -> 1.11]
# Parma: [24.98 -> 25.64] & [1.08 -> 0.93]
# 45.79%---------------------------------------------
# Cagliari vs Genoa -> Cagliari won
# Cagliari: [24.13 -> 24.81] & [1.94 -> 1.53]
# Genoa: [24.4 -> 24.03] & [1.12 -> 1.03]
# 46.05%---------------------------------------------
# Bologna vs Lazio -> Lazio won
# Bologna: [22.09 -> 22.06] & [1.78 -> 1.78]
# Lazio: [26.07 -> 26.15] & [1.01 -> 0.94]
# 46.32%---------------------------------------------
# Draw
# 46.58%---------------------------------------------
# Torino vs Empoli -> Torino won
# Torino: [25.63 -> 25.92] & [1.96 -> 1.75]
# Empoli: [23.92 -> 23.77] & [1.21 -> 1.14]
# 46.84%---------------------------------------------
# Draw
# 47.11%---------------------------------------------
# Roma vs Sassuolo -> Roma won
# Roma: [24.82 -> 25.26] & [1.23 -> 1.03]
# Sassuolo: [25.42 -> 24.69] & [1.83 -> 1.41]
# 47.37%---------------------------------------------
# Inter vs Napoli -> Inter won
# Inter: [26.96 -> 27.6] & [1.13 -> 0.91]
# Napoli: [28.4 -> 27.62] & [1.45 -> 1.18]
# 47.63%---------------------------------------------
# Juventus vs Sampdoria -> Juventus won
# Juventus: [30.85 -> 30.91] & [2.25 -> 2.21]
# Sampdoria: [25.55 -> 25.54] & [1.11 -> 1.04]
# 47.89%---------------------------------------------
# Udinese vs Cagliari -> Udinese won
# Udinese: [23.24 -> 23.97] & [1.4 -> 1.15]
# Cagliari: [24.81 -> 24.05] & [1.53 -> 1.2]
# 48.16%---------------------------------------------
# Sassuolo vs Atalanta -> Atalanta won
# Sassuolo: [24.69 -> 24.26] & [1.41 -> 1.21]
# Atalanta: [25.24 -> 25.47] & [0.83 -> 0.73]
# 48.42%---------------------------------------------
# Parma vs Roma -> Roma won
# Parma: [25.64 -> 25.23] & [0.93 -> 0.77]
# Roma: [25.26 -> 25.74] & [1.03 -> 0.86]
# 48.68%---------------------------------------------
# Draw
# 48.95%---------------------------------------------
# Draw
# 49.21%---------------------------------------------
# Empoli vs Inter -> Inter won
# Empoli: [23.77 -> 23.66] & [1.14 -> 1.04]
# Inter: [27.6 -> 27.71] & [0.91 -> 0.88]
# 49.47%---------------------------------------------
# Chievo vs Frosinone -> Chievo won
# Chievo: [20.11 -> 21.24] & [2.96 -> 2.36]
# Frosinone: [22.06 -> 21.22] & [2.23 -> 1.84]
# 49.74%---------------------------------------------
# Napoli vs Bologna -> Napoli won
# Napoli: [27.62 -> 27.67] & [1.18 -> 1.16]
# Bologna: [22.06 -> 22.0] & [1.78 -> 1.67]
# 50.0%---------------------------------------------
# Milan vs Spal -> Milan won
# Milan: [26.71 -> 26.81] & [1.46 -> 1.45]
# Spal: [23.38 -> 23.26] & [1.6 -> 1.49]
# 50.26%---------------------------------------------
# Roma vs Torino -> Roma won
# Roma: [25.74 -> 26.04] & [0.86 -> 0.75]
# Torino: [25.92 -> 25.32] & [1.75 -> 1.37]
# 50.53%---------------------------------------------
# Udinese vs Parma -> Parma won
# Udinese: [23.97 -> 23.74] & [1.15 -> 0.94]
# Parma: [25.23 -> 25.4] & [0.77 -> 0.66]
# 50.79%---------------------------------------------
# Draw
# 51.05%---------------------------------------------
# Frosinone vs Atalanta -> Atalanta won
# Frosinone: [21.22 -> 21.17] & [1.84 -> 1.74]
# Atalanta: [25.47 -> 25.49] & [0.73 -> 0.7]
# 51.32%---------------------------------------------
# Draw
# 51.58%---------------------------------------------
# Draw
# 51.84%---------------------------------------------
# Draw
# 52.11%---------------------------------------------
# Napoli vs Lazio -> Napoli won
# Napoli: [27.67 -> 27.91] & [1.16 -> 1.02]
# Lazio: [26.15 -> 25.98] & [0.94 -> 0.82]
# 52.37%---------------------------------------------
# Genoa vs Milan -> Milan won
# Genoa: [24.03 -> 23.91] & [1.03 -> 0.95]
# Milan: [26.81 -> 26.92] & [1.45 -> 1.28]
# 52.63%---------------------------------------------
# Juventus vs Chievo -> Juventus won
# Juventus: [30.91 -> 30.87] & [2.21 -> 2.17]
# Chievo: [21.24 -> 21.32] & [2.36 -> 2.39]
# 52.89%---------------------------------------------
# Sassuolo vs Cagliari -> Sassuolo won
# Sassuolo: [24.26 -> 24.64] & [1.21 -> 1.06]
# Cagliari: [24.05 -> 23.65] & [1.2 -> 1.03]
# 53.16%---------------------------------------------
# Sampdoria vs Udinese -> Sampdoria won
# Sampdoria: [25.54 -> 25.73] & [1.04 -> 0.94]
# Udinese: [23.74 -> 23.57] & [0.94 -> 0.86]
# 53.42%---------------------------------------------
# Draw
# 53.68%---------------------------------------------
# Chievo vs Fiorentina -> Fiorentina won
# Chievo: [21.32 -> 21.23] & [2.39 -> 2.21]
# Fiorentina: [25.81 -> 25.83] & [1.11 -> 1.06]
# 53.95%---------------------------------------------
# Parma vs Spal -> Spal won
# Parma: [25.4 -> 24.87] & [0.66 -> 0.54]
# Spal: [23.26 -> 24.35] & [1.49 -> 1.02]
# 54.21%---------------------------------------------
# Bologna vs Frosinone -> Frosinone won
# Bologna: [22.0 -> 21.36] & [1.67 -> 1.36]
# Frosinone: [21.17 -> 21.85] & [1.74 -> 1.43]
# 54.47%---------------------------------------------
# Draw
# 54.74%---------------------------------------------
# Torino vs Inter -> Torino won
# Torino: [25.32 -> 26.38] & [1.37 -> 1.01]
# Inter: [27.71 -> 27.04] & [0.88 -> 0.75]
# 55.0%---------------------------------------------
# Lazio vs Juventus -> Juventus won
# Lazio: [25.98 -> 25.92] & [0.82 -> 0.85]
# Juventus: [30.87 -> 30.97] & [2.17 -> 2.16]
# 55.26%---------------------------------------------
# Empoli vs Genoa -> Genoa won
# Empoli: [23.66 -> 23.31] & [1.04 -> 0.9]
# Genoa: [23.91 -> 24.28] & [0.95 -> 0.83]
# 55.53%---------------------------------------------
# Draw
# 55.79%---------------------------------------------
# Napoli vs Sampdoria -> Napoli won
# Napoli: [27.91 -> 28.04] & [1.02 -> 0.96]
# Sampdoria: [25.73 -> 25.62] & [0.94 -> 0.81]
# 56.05%---------------------------------------------
# Draw
# 56.32%---------------------------------------------
# Draw
# 56.58%---------------------------------------------
# Draw
# 56.84%---------------------------------------------
# Draw
# 57.11%---------------------------------------------
# Inter vs Bologna -> Bologna won
# Inter: [27.04 -> 25.91] & [0.75 -> 0.6]
# Bologna: [21.36 -> 23.37] & [1.36 -> 0.92]
# 57.37%---------------------------------------------
# Draw
# 57.63%---------------------------------------------
# Frosinone vs Lazio -> Lazio won
# Frosinone: [21.85 -> 21.8] & [1.43 -> 1.35]
# Lazio: [25.92 -> 25.93] & [0.85 -> 0.84]
# 57.89%---------------------------------------------
# Cagliari vs Atalanta -> Atalanta won
# Cagliari: [23.65 -> 23.5] & [1.03 -> 0.9]
# Atalanta: [25.49 -> 25.59] & [0.7 -> 0.66]
# 58.16%---------------------------------------------
# Lazio vs Empoli -> Lazio won
# Lazio: [25.93 -> 26.05] & [0.84 -> 0.83]
# Empoli: [23.31 -> 23.2] & [0.9 -> 0.86]
# 58.42%---------------------------------------------
# Chievo vs Roma -> Roma won
# Chievo: [21.23 -> 21.16] & [2.21 -> 2.09]
# Roma: [26.04 -> 26.08] & [0.75 -> 0.73]
# 58.68%---------------------------------------------
# Draw
# 58.95%---------------------------------------------
# Parma vs Inter -> Inter won
# Parma: [24.87 -> 24.74] & [0.54 -> 0.49]
# Inter: [25.91 -> 26.07] & [0.6 -> 0.52]
# 59.21%---------------------------------------------
# Draw
# 59.47%---------------------------------------------
# Torino vs Udinese -> Torino won
# Torino: [26.38 -> 26.46] & [1.01 -> 0.95]
# Udinese: [23.57 -> 23.47] & [0.86 -> 0.81]
# 59.74%---------------------------------------------
# Sampdoria vs Frosinone -> Frosinone won
# Sampdoria: [25.62 -> 24.71] & [0.81 -> 0.65]
# Frosinone: [21.8 -> 23.22] & [1.35 -> 0.93]
# 60.0%---------------------------------------------
# Atalanta vs Spal -> Atalanta won
# Atalanta: [25.59 -> 25.73] & [0.66 -> 0.62]
# Spal: [24.35 -> 24.12] & [1.02 -> 0.88]
# 60.26%---------------------------------------------
# Sassuolo vs Juventus -> Juventus won
# Sassuolo: [24.64 -> 24.66] & [1.06 -> 1.07]
# Juventus: [30.97 -> 30.94] & [2.16 -> 2.12]
# 60.53%---------------------------------------------
# Milan vs Cagliari -> Milan won
# Milan: [26.92 -> 26.99] & [1.28 -> 1.28]
# Cagliari: [23.5 -> 23.49] & [0.9 -> 0.89]
# 60.79%---------------------------------------------
# Juventus vs Frosinone -> Juventus won
# Juventus: [30.94 -> 30.88] & [2.12 -> 2.07]
# Frosinone: [23.22 -> 23.21] & [0.93 -> 0.93]
# 61.05%---------------------------------------------
# Cagliari vs Parma -> Cagliari won
# Cagliari: [23.49 -> 24.21] & [0.89 -> 0.67]
# Parma: [24.74 -> 24.34] & [0.49 -> 0.43]
# 61.32%---------------------------------------------
# Atalanta vs Milan -> Milan won
# Atalanta: [25.73 -> 25.58] & [0.62 -> 0.58]
# Milan: [26.99 -> 27.32] & [1.28 -> 1.05]
# 61.58%---------------------------------------------
# Spal vs Fiorentina -> Fiorentina won
# Spal: [24.12 -> 23.96] & [0.88 -> 0.78]
# Fiorentina: [25.83 -> 26.11] & [1.06 -> 0.96]
# 61.84%---------------------------------------------
# Udinese vs Chievo -> Udinese won
# Udinese: [23.47 -> 23.57] & [0.81 -> 0.8]
# Chievo: [21.16 -> 20.89] & [2.09 -> 1.74]
# 62.11%---------------------------------------------
# Genoa vs Lazio -> Genoa won
# Genoa: [24.28 -> 24.96] & [0.83 -> 0.62]
# Lazio: [26.05 -> 25.38] & [0.83 -> 0.66]
# 62.37%---------------------------------------------
# Empoli vs Sassuolo -> Empoli won
# Empoli: [23.2 -> 23.8] & [0.86 -> 0.71]
# Sassuolo: [24.66 -> 23.98] & [1.07 -> 0.84]
# 62.63%---------------------------------------------
# Inter vs Sampdoria -> Inter won
# Inter: [26.07 -> 26.2] & [0.52 -> 0.48]
# Sampdoria: [24.71 -> 24.54] & [0.65 -> 0.57]
# 62.89%---------------------------------------------
# Draw
# 63.16%---------------------------------------------
# Roma vs Bologna -> Roma won
# Roma: [26.08 -> 26.13] & [0.73 -> 0.73]
# Bologna: [23.37 -> 23.34] & [0.92 -> 0.82]
# 63.42%---------------------------------------------
# Milan vs Empoli -> Milan won
# Milan: [27.32 -> 27.32] & [1.05 -> 1.02]
# Empoli: [23.8 -> 23.81] & [0.71 -> 0.69]
# 63.68%---------------------------------------------
# Torino vs Atalanta -> Torino won
# Torino: [26.46 -> 26.74] & [0.95 -> 0.86]
# Atalanta: [25.58 -> 25.38] & [0.58 -> 0.51]
# 63.95%---------------------------------------------
# Frosinone vs Roma -> Roma won
# Frosinone: [23.21 -> 23.09] & [0.93 -> 0.84]
# Roma: [26.13 -> 26.17] & [0.73 -> 0.71]
# 64.21%---------------------------------------------
# Sampdoria vs Cagliari -> Sampdoria won
# Sampdoria: [24.54 -> 24.8] & [0.57 -> 0.5]
# Cagliari: [24.21 -> 23.91] & [0.67 -> 0.59]
# 64.47%---------------------------------------------
# Draw
# 64.74%---------------------------------------------
# Draw
# 65.0%---------------------------------------------
# Bologna vs Juventus -> Juventus won
# Bologna: [23.34 -> 23.33] & [0.82 -> 0.83]
# Juventus: [30.88 -> 30.92] & [2.07 -> 2.05]
# 65.26%---------------------------------------------
# Parma vs Napoli -> Napoli won
# Parma: [24.34 -> 24.31] & [0.43 -> 0.4]
# Napoli: [28.04 -> 28.11] & [0.96 -> 0.93]
# 65.53%---------------------------------------------
# Draw
# 65.79%---------------------------------------------
# Cagliari vs Inter -> Cagliari won
# Cagliari: [23.91 -> 24.7] & [0.59 -> 0.48]
# Inter: [26.2 -> 25.54] & [0.48 -> 0.39]
# 66.05%---------------------------------------------
# Draw
# 66.32%---------------------------------------------
# Milan vs Sassuolo -> Milan won
# Milan: [27.32 -> 27.35] & [1.02 -> 1.0]
# Sassuolo: [23.98 -> 23.92] & [0.84 -> 0.84]
# 66.58%---------------------------------------------
# Lazio vs Roma -> Lazio won
# Lazio: [25.38 -> 25.82] & [0.66 -> 0.56]
# Roma: [26.17 -> 25.69] & [0.71 -> 0.57]
# 66.84%---------------------------------------------
# Torino vs Chievo -> Torino won
# Torino: [26.74 -> 26.71] & [0.86 -> 0.81]
# Chievo: [20.89 -> 20.9] & [1.74 -> 1.7]
# 67.11%---------------------------------------------
# Udinese vs Bologna -> Udinese won
# Udinese: [23.57 -> 23.85] & [0.8 -> 0.67]
# Bologna: [23.33 -> 23.0] & [0.83 -> 0.7]
# 67.37%---------------------------------------------
# Spal vs Sampdoria -> Sampdoria won
# Spal: [23.96 -> 23.76] & [0.78 -> 0.65]
# Sampdoria: [24.8 -> 24.95] & [0.5 -> 0.43]
# 67.63%---------------------------------------------
# Draw
# 67.89%---------------------------------------------
# Atalanta vs Fiorentina -> Atalanta won
# Atalanta: [25.38 -> 25.7] & [0.51 -> 0.44]
# Fiorentina: [26.11 -> 25.53] & [0.96 -> 0.73]
# 68.16%---------------------------------------------
# Napoli vs Juventus -> Juventus won
# Napoli: [28.11 -> 28.01] & [0.93 -> 0.92]
# Juventus: [30.92 -> 31.1] & [2.05 -> 1.86]
# 68.42%---------------------------------------------
# Juventus vs Udinese -> Juventus won
# Juventus: [31.1 -> 31.11] & [1.86 -> 1.83]
# Udinese: [23.85 -> 23.83] & [0.67 -> 0.69]
# 68.68%---------------------------------------------
# Parma vs Genoa -> Parma won
# Parma: [24.31 -> 24.65] & [0.4 -> 0.35]
# Genoa: [24.96 -> 24.51] & [0.62 -> 0.51]
# 68.95%---------------------------------------------
# Chievo vs Milan -> Milan won
# Chievo: [20.9 -> 20.91] & [1.7 -> 1.7]
# Milan: [27.35 -> 27.36] & [1.0 -> 1.08]
# 69.21%---------------------------------------------
# Bologna vs Cagliari -> Bologna won
# Bologna: [23.0 -> 23.75] & [0.7 -> 0.54]
# Cagliari: [24.7 -> 24.17] & [0.48 -> 0.4]
# 69.47%---------------------------------------------
# Sampdoria vs Atalanta -> Atalanta won
# Sampdoria: [24.95 -> 24.8] & [0.43 -> 0.4]
# Atalanta: [25.7 -> 25.86] & [0.44 -> 0.37]
# 69.74%---------------------------------------------
# Inter vs Spal -> Inter won
# Inter: [25.54 -> 25.59] & [0.39 -> 0.36]
# Spal: [23.76 -> 23.69] & [0.65 -> 0.56]
# 70.0%---------------------------------------------
# Frosinone vs Torino -> Torino won
# Frosinone: [23.09 -> 23.01] & [0.84 -> 0.82]
# Torino: [26.71 -> 26.77] & [0.81 -> 0.76]
# 70.26%---------------------------------------------
# Draw
# 70.53%---------------------------------------------
# Draw
# 70.79%---------------------------------------------
# Roma vs Empoli -> Roma won
# Roma: [25.69 -> 25.76] & [0.57 -> 0.53]
# Empoli: [23.81 -> 23.7] & [0.69 -> 0.63]
# 71.05%---------------------------------------------
# Cagliari vs Fiorentina -> Cagliari won
# Cagliari: [24.17 -> 24.55] & [0.4 -> 0.35]
# Fiorentina: [25.53 -> 24.83] & [0.73 -> 0.56]
# 71.32%---------------------------------------------
# Sassuolo vs Sampdoria -> Sampdoria won
# Sassuolo: [23.92 -> 23.66] & [0.84 -> 0.7]
# Sampdoria: [24.8 -> 24.91] & [0.4 -> 0.38]
# 71.58%---------------------------------------------
# Spal vs Roma -> Spal won
# Spal: [23.69 -> 24.39] & [0.56 -> 0.44]
# Roma: [25.76 -> 25.08] & [0.53 -> 0.43]
# 71.84%---------------------------------------------
# Torino vs Bologna -> Bologna won
# Torino: [26.77 -> 25.7] & [0.76 -> 0.56]
# Bologna: [23.75 -> 24.51] & [0.54 -> 0.44]
# 72.11%---------------------------------------------
# Genoa vs Juventus -> Genoa won
# Genoa: [24.51 -> 25.27] & [0.51 -> 0.48]
# Juventus: [31.11 -> 28.3] & [1.83 -> 1.12]
# 72.37%---------------------------------------------
# Lazio vs Parma -> Lazio won
# Lazio: [25.82 -> 25.97] & [0.56 -> 0.48]
# Parma: [24.65 -> 24.55] & [0.35 -> 0.31]
# 72.63%---------------------------------------------
# Empoli vs Frosinone -> Empoli won
# Empoli: [23.7 -> 23.92] & [0.63 -> 0.55]
# Frosinone: [23.01 -> 22.71] & [0.82 -> 0.69]
# 72.89%---------------------------------------------
# Draw
# 73.16%---------------------------------------------
# Napoli vs Udinese -> Napoli won
# Napoli: [28.01 -> 27.99] & [0.92 -> 0.92]
# Udinese: [23.83 -> 23.88] & [0.69 -> 0.69]
# 73.42%---------------------------------------------
# Milan vs Inter -> Inter won
# Milan: [27.36 -> 26.36] & [1.08 -> 0.74]
# Inter: [25.59 -> 25.9] & [0.36 -> 0.32]
# 73.68%---------------------------------------------
# Chievo vs Cagliari -> Cagliari won
# Chievo: [20.91 -> 20.9] & [1.7 -> 1.56]
# Cagliari: [24.55 -> 24.56] & [0.35 -> 0.35]
# 73.95%---------------------------------------------
# Udinese vs Genoa -> Udinese won
# Udinese: [23.88 -> 24.54] & [0.69 -> 0.55]
# Genoa: [25.27 -> 24.82] & [0.48 -> 0.41]
# 74.21%---------------------------------------------
# Juventus vs Empoli -> Juventus won
# Juventus: [28.3 -> 28.27] & [1.12 -> 1.14]
# Empoli: [23.92 -> 23.93] & [0.55 -> 0.56]
# 74.47%---------------------------------------------
# Sampdoria vs Milan -> Sampdoria won
# Sampdoria: [24.91 -> 25.3] & [0.38 -> 0.33]
# Milan: [26.36 -> 25.62] & [0.74 -> 0.53]
# 74.74%---------------------------------------------
# Parma vs Atalanta -> Atalanta won
# Parma: [24.55 -> 24.47] & [0.31 -> 0.29]
# Atalanta: [25.86 -> 25.94] & [0.37 -> 0.32]
# 75.0%---------------------------------------------
# Roma vs Napoli -> Napoli won
# Roma: [25.08 -> 25.05] & [0.43 -> 0.42]
# Napoli: [27.99 -> 28.04] & [0.92 -> 0.87]
# 75.26%---------------------------------------------
# Frosinone vs Spal -> Spal won
# Frosinone: [22.71 -> 22.58] & [0.69 -> 0.64]
# Spal: [24.39 -> 24.47] & [0.44 -> 0.41]
# 75.53%---------------------------------------------
# Draw
# 75.79%---------------------------------------------
# Bologna vs Sassuolo -> Bologna won
# Bologna: [24.51 -> 24.67] & [0.44 -> 0.4]
# Sassuolo: [23.66 -> 23.42] & [0.7 -> 0.62]
# 76.05%---------------------------------------------
# Inter vs Lazio -> Lazio won
# Inter: [25.9 -> 25.72] & [0.32 -> 0.28]
# Lazio: [25.97 -> 26.24] & [0.48 -> 0.38]
# 76.32%---------------------------------------------
# Draw
# 76.58%---------------------------------------------
# Cagliari vs Juventus -> Juventus won
# Cagliari: [24.56 -> 24.53] & [0.35 -> 0.35]
# Juventus: [28.27 -> 28.29] & [1.14 -> 1.05]
# 76.84%---------------------------------------------
# Empoli vs Napoli -> Empoli won
# Empoli: [23.93 -> 24.83] & [0.56 -> 0.46]
# Napoli: [28.04 -> 26.63] & [0.87 -> 0.66]
# 77.11%---------------------------------------------
# Torino vs Sampdoria -> Torino won
# Torino: [25.7 -> 25.98] & [0.56 -> 0.45]
# Sampdoria: [25.3 -> 25.16] & [0.33 -> 0.29]
# 77.37%---------------------------------------------
# Spal vs Lazio -> Spal won
# Spal: [24.47 -> 25.07] & [0.41 -> 0.31]
# Lazio: [26.24 -> 25.67] & [0.38 -> 0.31]
# 77.63%---------------------------------------------
# Draw
# 77.89%---------------------------------------------
# Genoa vs Inter -> Inter won
# Genoa: [24.82 -> 24.7] & [0.41 -> 0.34]
# Inter: [25.72 -> 25.8] & [0.28 -> 0.25]
# 78.16%---------------------------------------------
# Frosinone vs Parma -> Frosinone won
# Frosinone: [22.58 -> 23.44] & [0.64 -> 0.46]
# Parma: [24.47 -> 24.06] & [0.29 -> 0.24]
# 78.42%---------------------------------------------
# Sassuolo vs Chievo -> Sassuolo won
# Sassuolo: [23.42 -> 23.5] & [0.62 -> 0.59]
# Chievo: [20.9 -> 20.69] & [1.56 -> 1.43]
# 78.68%---------------------------------------------
# Atalanta vs Bologna -> Atalanta won
# Atalanta: [25.94 -> 26.01] & [0.32 -> 0.3]
# Bologna: [24.67 -> 24.6] & [0.4 -> 0.36]
# 78.95%---------------------------------------------
# Draw
# 79.21%---------------------------------------------
# Juventus vs Milan -> Juventus won
# Juventus: [28.29 -> 28.33] & [1.05 -> 0.95]
# Milan: [25.62 -> 25.61] & [0.53 -> 0.5]
# 79.47%---------------------------------------------
# Sampdoria vs Roma -> Roma won
# Sampdoria: [25.16 -> 24.95] & [0.29 -> 0.26]
# Roma: [25.05 -> 25.36] & [0.42 -> 0.33]
# 79.74%---------------------------------------------
# Fiorentina vs Frosinone -> Frosinone won
# Fiorentina: [24.83 -> 24.24] & [0.56 -> 0.42]
# Frosinone: [23.44 -> 23.91] & [0.46 -> 0.38]
# 80.0%---------------------------------------------
# Udinese vs Empoli -> Udinese won
# Udinese: [24.54 -> 24.92] & [0.55 -> 0.45]
# Empoli: [24.83 -> 24.56] & [0.46 -> 0.38]
# 80.26%---------------------------------------------
# Cagliari vs Spal -> Cagliari won
# Cagliari: [24.53 -> 24.88] & [0.35 -> 0.29]
# Spal: [25.07 -> 24.79] & [0.31 -> 0.25]
# 80.53%---------------------------------------------
# Draw
# 80.79%---------------------------------------------
# Draw
# 81.05%---------------------------------------------
# Draw
# 81.32%---------------------------------------------
# Bologna vs Chievo -> Bologna won
# Bologna: [24.6 -> 24.6] & [0.36 -> 0.33]
# Chievo: [20.69 -> 20.65] & [1.43 -> 1.43]
# 81.58%---------------------------------------------
# Spal vs Juventus -> Spal won
# Spal: [24.79 -> 25.2] & [0.25 -> 0.23]
# Juventus: [28.33 -> 26.71] & [0.95 -> 0.62]
# 81.84%---------------------------------------------
# Roma vs Udinese -> Roma won
# Roma: [25.36 -> 25.52] & [0.33 -> 0.29]
# Udinese: [24.92 -> 24.73] & [0.45 -> 0.4]
# 82.11%---------------------------------------------
# Milan vs Lazio -> Milan won
# Milan: [25.61 -> 25.97] & [0.5 -> 0.38]
# Lazio: [25.67 -> 25.46] & [0.31 -> 0.27]
# 82.37%---------------------------------------------
# Draw
# 82.63%---------------------------------------------
# Draw
# 82.89%---------------------------------------------
# Sampdoria vs Genoa -> Sampdoria won
# Sampdoria: [24.95 -> 25.1] & [0.26 -> 0.23]
# Genoa: [24.7 -> 24.49] & [0.34 -> 0.29]
# 83.16%---------------------------------------------
# Draw
# 83.42%---------------------------------------------
# Chievo vs Napoli -> Napoli won
# Chievo: [20.65 -> 20.69] & [1.43 -> 1.45]
# Napoli: [26.63 -> 26.63] & [0.66 -> 0.67]
# 83.68%---------------------------------------------
# Frosinone vs Inter -> Inter won
# Frosinone: [23.91 -> 23.85] & [0.38 -> 0.36]
# Inter: [25.8 -> 25.81] & [0.25 -> 0.24]
# 83.95%---------------------------------------------
# Draw
# 84.21%---------------------------------------------
# Lazio vs Udinese -> Lazio won
# Lazio: [25.46 -> 25.56] & [0.27 -> 0.25]
# Udinese: [24.73 -> 24.58] & [0.4 -> 0.34]
# 84.47%---------------------------------------------
# Draw
# 84.74%---------------------------------------------
# Draw
# 85.0%---------------------------------------------
# Lazio vs Chievo -> Chievo won
# Lazio: [25.56 -> 25.16] & [0.25 -> 0.25]
# Chievo: [20.69 -> 23.02] & [1.45 -> 0.85]
# 85.26%---------------------------------------------
# Genoa vs Torino -> Torino won
# Genoa: [24.49 -> 24.43] & [0.29 -> 0.27]
# Torino: [25.98 -> 26.06] & [0.45 -> 0.41]
# 85.53%---------------------------------------------
# Empoli vs Spal -> Spal won
# Empoli: [24.56 -> 24.39] & [0.38 -> 0.33]
# Spal: [25.2 -> 25.28] & [0.23 -> 0.21]
# 85.79%---------------------------------------------
# Cagliari vs Frosinone -> Cagliari won
# Cagliari: [24.88 -> 24.97] & [0.29 -> 0.26]
# Frosinone: [23.85 -> 23.76] & [0.36 -> 0.33]
# 86.05%---------------------------------------------
# Bologna vs Sampdoria -> Bologna won
# Bologna: [24.6 -> 24.97] & [0.33 -> 0.28]
# Sampdoria: [25.1 -> 24.83] & [0.23 -> 0.18]
# 86.32%---------------------------------------------
# Juventus vs Fiorentina -> Juventus won
# Juventus: [26.71 -> 26.78] & [0.62 -> 0.6]
# Fiorentina: [24.24 -> 24.18] & [0.42 -> 0.42]
# 86.58%---------------------------------------------
# Draw
# 86.84%---------------------------------------------
# Napoli vs Atalanta -> Atalanta won
# Napoli: [26.63 -> 26.08] & [0.67 -> 0.5]
# Atalanta: [26.01 -> 26.25] & [0.3 -> 0.29]
# 87.11%---------------------------------------------
# Bologna vs Empoli -> Bologna won
# Bologna: [24.97 -> 25.06] & [0.28 -> 0.24]
# Empoli: [24.39 -> 24.25] & [0.33 -> 0.27]
# 87.37%---------------------------------------------
# Roma vs Cagliari -> Roma won
# Roma: [25.52 -> 25.65] & [0.29 -> 0.25]
# Cagliari: [24.97 -> 24.85] & [0.26 -> 0.23]
# 87.63%---------------------------------------------
# Draw
# 87.89%---------------------------------------------
# Frosinone vs Napoli -> Napoli won
# Frosinone: [23.76 -> 23.74] & [0.33 -> 0.34]
# Napoli: [26.08 -> 26.13] & [0.5 -> 0.48]
# 88.16%---------------------------------------------
# Draw
# 88.42%---------------------------------------------
# Draw
# 88.68%---------------------------------------------
# Sampdoria vs Lazio -> Lazio won
# Sampdoria: [24.83 -> 24.71] & [0.18 -> 0.16]
# Lazio: [25.16 -> 25.3] & [0.25 -> 0.2]
# 88.95%---------------------------------------------
# Torino vs Milan -> Torino won
# Torino: [26.06 -> 26.31] & [0.41 -> 0.33]
# Milan: [25.97 -> 25.72] & [0.38 -> 0.31]
# 89.21%---------------------------------------------
# Atalanta vs Udinese -> Atalanta won
# Atalanta: [26.25 -> 26.32] & [0.29 -> 0.29]
# Udinese: [24.58 -> 24.54] & [0.34 -> 0.32]
# 89.47%---------------------------------------------
# Fiorentina vs Sassuolo -> Sassuolo won
# Fiorentina: [24.18 -> 23.85] & [0.42 -> 0.37]
# Sassuolo: [23.5 -> 23.95] & [0.59 -> 0.46]
# 89.74%---------------------------------------------
# Draw
# 90.0%---------------------------------------------
# Chievo vs Spal -> Spal won
# Chievo: [23.02 -> 23.0] & [0.85 -> 0.73]
# Spal: [25.28 -> 25.31] & [0.21 -> 0.2]
# 90.26%---------------------------------------------
# Draw
# 90.53%---------------------------------------------
# Empoli vs Fiorentina -> Empoli won
# Empoli: [24.25 -> 24.41] & [0.27 -> 0.25]
# Fiorentina: [23.85 -> 23.64] & [0.37 -> 0.31]
# 90.79%---------------------------------------------
# Draw
# 91.05%---------------------------------------------
# Draw
# 91.32%---------------------------------------------
# Lazio vs Atalanta -> Atalanta won
# Lazio: [25.3 -> 25.25] & [0.2 -> 0.17]
# Atalanta: [26.32 -> 26.4] & [0.29 -> 0.26]
# 91.58%---------------------------------------------
# Draw
# 91.84%---------------------------------------------
# Napoli vs Cagliari -> Napoli won
# Napoli: [26.13 -> 26.21] & [0.48 -> 0.43]
# Cagliari: [24.85 -> 24.79] & [0.23 -> 0.21]
# 92.11%---------------------------------------------
# Milan vs Bologna -> Milan won
# Milan: [25.72 -> 25.87] & [0.31 -> 0.27]
# Bologna: [25.06 -> 24.96] & [0.24 -> 0.21]
# 92.37%---------------------------------------------
# Atalanta vs Genoa -> Atalanta won
# Atalanta: [26.4 -> 26.42] & [0.26 -> 0.25]
# Genoa: [24.43 -> 24.42] & [0.27 -> 0.26]
# 92.63%---------------------------------------------
# Cagliari vs Lazio -> Lazio won
# Cagliari: [24.79 -> 24.68] & [0.21 -> 0.19]
# Lazio: [25.25 -> 25.35] & [0.17 -> 0.14]
# 92.89%---------------------------------------------
# Fiorentina vs Milan -> Milan won
# Fiorentina: [23.64 -> 23.6] & [0.31 -> 0.31]
# Milan: [25.87 -> 25.9] & [0.27 -> 0.27]
# 93.16%---------------------------------------------
# Torino vs Sassuolo -> Torino won
# Torino: [26.31 -> 26.34] & [0.33 -> 0.33]
# Sassuolo: [23.95 -> 23.9] & [0.46 -> 0.48]
# 93.42%---------------------------------------------
# Sampdoria vs Empoli -> Empoli won
# Sampdoria: [24.71 -> 24.54] & [0.16 -> 0.14]
# Empoli: [24.41 -> 24.7] & [0.25 -> 0.2]
# 93.68%---------------------------------------------
# Frosinone vs Udinese -> Udinese won
# Frosinone: [23.74 -> 23.63] & [0.34 -> 0.31]
# Udinese: [24.54 -> 24.65] & [0.32 -> 0.29]
# 93.95%---------------------------------------------
# Spal vs Napoli -> Napoli won
# Spal: [25.31 -> 25.24] & [0.2 -> 0.18]
# Napoli: [26.21 -> 26.36] & [0.43 -> 0.39]
# 94.21%---------------------------------------------
# Roma vs Juventus -> Roma won
# Roma: [25.65 -> 25.95] & [0.25 -> 0.23]
# Juventus: [26.78 -> 26.13] & [0.6 -> 0.41]
# 94.47%---------------------------------------------
# Bologna vs Parma -> Bologna won
# Bologna: [24.96 -> 25.04] & [0.21 -> 0.18]
# Parma: [24.06 -> 23.99] & [0.24 -> 0.21]
# 94.74%---------------------------------------------
# Inter vs Chievo -> Inter won
# Inter: [25.81 -> 25.82] & [0.24 -> 0.24]
# Chievo: [23.0 -> 22.99] & [0.73 -> 0.68]
# 95.0%---------------------------------------------
# Udinese vs Spal -> Udinese won
# Udinese: [24.65 -> 25.02] & [0.29 -> 0.23]
# Spal: [25.24 -> 25.04] & [0.18 -> 0.16]
# 95.26%---------------------------------------------
# Draw
# 95.53%---------------------------------------------
# Draw
# 95.79%---------------------------------------------
# Draw
# 96.05%---------------------------------------------
# Parma vs Fiorentina -> Parma won
# Parma: [23.99 -> 24.12] & [0.21 -> 0.19]
# Fiorentina: [23.6 -> 23.42] & [0.31 -> 0.26]
# 96.32%---------------------------------------------
# Empoli vs Torino -> Empoli won
# Empoli: [24.7 -> 25.08] & [0.2 -> 0.16]
# Torino: [26.34 -> 25.68] & [0.33 -> 0.23]
# 96.58%---------------------------------------------
# Milan vs Frosinone -> Milan won
# Milan: [25.9 -> 25.92] & [0.27 -> 0.26]
# Frosinone: [23.63 -> 23.6] & [0.31 -> 0.29]
# 96.84%---------------------------------------------
# Napoli vs Inter -> Napoli won
# Napoli: [26.36 -> 26.53] & [0.39 -> 0.32]
# Inter: [25.82 -> 25.71] & [0.24 -> 0.22]
# 97.11%---------------------------------------------
# Draw
# 97.37%---------------------------------------------
# Draw
# 97.63%---------------------------------------------
# Draw
# 97.89%---------------------------------------------
# Bologna vs Napoli -> Bologna won
# Bologna: [25.04 -> 25.39] & [0.18 -> 0.16]
# Napoli: [26.53 -> 25.91] & [0.32 -> 0.23]
# 98.16%---------------------------------------------
# Torino vs Lazio -> Torino won
# Torino: [25.68 -> 25.82] & [0.23 -> 0.19]
# Lazio: [25.35 -> 25.26] & [0.14 -> 0.12]
# 98.42%---------------------------------------------
# Sampdoria vs Juventus -> Sampdoria won
# Sampdoria: [24.54 -> 24.79] & [0.14 -> 0.12]
# Juventus: [26.13 -> 25.36] & [0.41 -> 0.3]
# 98.68%---------------------------------------------
# Spal vs Milan -> Milan won
# Spal: [25.04 -> 24.99] & [0.16 -> 0.15]
# Milan: [25.92 -> 26.0] & [0.26 -> 0.23]
# 98.95%---------------------------------------------
# Roma vs Parma -> Roma won
# Roma: [25.95 -> 26.0] & [0.23 -> 0.24]
# Parma: [24.12 -> 24.1] & [0.19 -> 0.19]
# 99.21%---------------------------------------------
# Inter vs Empoli -> Inter won
# Inter: [25.71 -> 25.83] & [0.22 -> 0.2]
# Empoli: [25.08 -> 25.0] & [0.16 -> 0.15]
# 99.47%---------------------------------------------
# Draw
# 99.74%---------------------------------------------
# Cagliari vs Udinese -> Udinese won
# Cagliari: [24.68 -> 24.58] & [0.19 -> 0.16]
# Udinese: [25.02 -> 25.16] & [0.23 -> 0.18]
# 100.0%---------------------------------------------
# Atalanta vs Sassuolo -> Atalanta won
# Atalanta: [26.42 -> 26.44] & [0.25 -> 0.24]
# Sassuolo: [23.9 -> 23.91] & [0.48 -> 0.45]

# %%
print(team_skills)
# Out:
# {'Chievo': [22.780234135230785, 0.6777404097675546], 'Lazio': [25.210560472653288, 0.14040487476826163], 'Torino': [25.83117178264061, 0.22648984157205534], 'Sassuolo': [23.843582767096457, 0.3526920946911806], 'Parma': [23.97934332361046, 0.2226270733955427], 'Empoli': [24.95614028086093, 0.14165710019235703], 'Bologna': [25.494822818601904, 0.17515749124374552], 'Atalanta': [26.29987258990828, 0.17113147900510073], 'Juventus': [25.247896206725088, 0.36499030678345773], 'Napoli': [25.973493179741748, 0.16704190932843832], 'Spal': [24.87261242044239, 0.2083096654255958], 'Udinese': [25.030600303480995, 0.19957036600463135], 'Inter': [25.90122803205224, 0.2101697589392699], 'Genoa': [24.26413973867748, 0.3192191969429996], 'Frosinone': [23.437766815413998, 0.2811523871474512], 'Fiorentina': [23.237370969369714, 0.27747365254554357], 'Cagliari': [24.387961607857044, 0.13289114710506134], 'Roma': [26.005369855093647, 0.3047807292359742], 'Milan': [26.032025684002843, 0.2212755542867648], 'Sampdoria': [24.761201383806135, 0.14758059961664932]}

# %%
# print prior distribution of teams in descending order of mean
sorted_teams = sorted(team_skills.keys(), key = lambda k: team_skills[k][0], reverse=True)

for i in range(len(sorted_teams)):
    print(f"{sorted_teams[i]}: {round(team_skills[sorted_teams[i]][0],2)}, {round(team_skills[sorted_teams[i]][1],2)}")
# Out:
# Atalanta: 26.4, 0.23
# Milan: 25.98, 0.24
# Napoli: 25.95, 0.22
# Roma: 25.95, 0.23
# Torino: 25.81, 0.25
# Inter: 25.77, 0.21
# Juventus: 25.42, 0.29
# Bologna: 25.38, 0.16
# Udinese: 25.16, 0.19
# Lazio: 25.13, 0.14
# Empoli: 24.99, 0.17
# Spal: 24.92, 0.16
# Sampdoria: 24.85, 0.13
# Cagliari: 24.49, 0.17
# Genoa: 24.49, 0.27
# Parma: 24.0, 0.2
# Sassuolo: 23.82, 0.35
# Frosinone: 23.64, 0.22
# Fiorentina: 23.4, 0.2
# Chievo: 22.85, 0.58

# %%
def prediction(mu_s1, sig_s1, mu_s2, sig_s2):

    mu_t = mu_s1 - mu_s2
    sig_t = sig_s1 + sig_s2

    #cdf to find prob

    # z-score for 0
    zscore = (0 - mu_t) / np.sqrt(sig_t)
    prob = 1 - scipy.stats.norm.cdf(zscore)

    if prob > 0.5:
        return 1
    else: return -1

# %%
# prediction(team_skills["Parma"][0], team_skills["Parma"][1], team_skills["Atalanta"][0], team_skills["Atalanta"][1])
prediction(25, 8, 25 ,8)
# Out:
# -1

# %%
# Q6

n_tot = 0
n_cor = 0

for index, match in data.iterrows():
    # identify teams
    team1 = match['team1']
    team2 = match['team2']
    print(f"{round(100*(index+1)/380,2)}%---------------------------------------------")

    #ignore draws
    if(match["score1"] == match["score2"]):
        print("Draw")
        continue

    # find current team values
    mu_s1, mu_s2 = team_skills[team1][0], team_skills[team2][0]
    var_s1, var_s2 = team_skills[team1][1], team_skills[team2][1]

    #number of iterations in gibbs sampling
    iter = 1000

    #check what team won
    if(match["score1"] > match["score2"]):
        y = 1
        print(f"{team1} vs {team2} -> {team1} won")
    else:
        y = -1
        print(f"{team1} vs {team2} -> {team2} won")

    # try predict
    pred = prediction(mu_s1, var_s1, mu_s2, var_s2)

    if pred == y:
        n_cor += 1 
        print("prediction was correct")
    else:
        print("prediciton was wrong")


    # call sample func
    s1, s2, t = gibbs_sample(2500, 500, mu_s1, var_s1, mu_s2, var_s2, y)

    

    #calc new mean and var
    new_mu_s1 = np.mean(s1)
    new_mu_s2 = np.mean(s2)
    
    new_var_s1 = np.var(s1)
    new_var_s2 = np.var(s2)

    print(f"{team1}: [{round(mu_s1,2)} -> {round(new_mu_s1,2)}] & [{round(var_s1,2)} -> {round(new_var_s1,2)}]") 
    print(f"{team2}: [{round(mu_s2,2)} -> {round(new_mu_s2,2)}] & [{round(var_s2,2)} -> {round(new_var_s2,2)}]")


    team_skills[team1] = [new_mu_s1, new_var_s1]
    team_skills[team2] = [new_mu_s2, new_var_s2]

    n_tot += 1
# Out:
# 0.26%---------------------------------------------
# Chievo vs Juventus -> Juventus won
# prediction was correct
# Chievo: [23.75 -> 23.08] & [6.64 -> 5.68]
# Juventus: [26.12 -> 26.86] & [6.74 -> 5.92]
# 0.53%---------------------------------------------
# Lazio vs Napoli -> Napoli won
# prediction was correct
# Lazio: [23.87 -> 23.1] & [6.92 -> 6.17]
# Napoli: [26.28 -> 26.86] & [6.92 -> 6.05]
# 0.79%---------------------------------------------
# Torino vs Roma -> Roma won
# prediction was correct
# Torino: [25 -> 23.79] & [8.33 -> 7.01]
# Roma: [25 -> 26.24] & [8.33 -> 6.66]
# 1.05%---------------------------------------------
# Sassuolo vs Inter -> Sassuolo won
# prediciton was wrong
# Sassuolo: [25 -> 26.2] & [8.33 -> 6.98]
# Inter: [25 -> 23.86] & [8.33 -> 6.79]
# 1.32%---------------------------------------------
# Draw
# 1.58%---------------------------------------------
# Empoli vs Cagliari -> Empoli won
# prediciton was wrong
# Empoli: [25 -> 26.03] & [8.33 -> 6.97]
# Cagliari: [25 -> 24.0] & [8.33 -> 6.69]
# 1.84%---------------------------------------------
# Bologna vs Spal -> Spal won
# prediction was correct
# Bologna: [25 -> 23.82] & [8.33 -> 6.95]
# Spal: [25 -> 26.12] & [8.33 -> 7.09]
# 2.11%---------------------------------------------
# Atalanta vs Frosinone -> Atalanta won
# prediciton was wrong
# Atalanta: [25 -> 26.27] & [8.33 -> 6.89]
# Frosinone: [25 -> 23.77] & [8.33 -> 6.89]
# 2.37%---------------------------------------------
# Juventus vs Lazio -> Juventus won
# prediction was correct
# Juventus: [26.86 -> 27.28] & [5.92 -> 5.15]
# Lazio: [23.1 -> 22.59] & [6.17 -> 5.34]
# 2.63%---------------------------------------------
# Napoli vs Milan -> Napoli won
# prediction was correct
# Napoli: [26.86 -> 27.59] & [6.05 -> 5.64]
# Milan: [25 -> 24.05] & [8.33 -> 6.77]
# 2.89%---------------------------------------------
# Spal vs Parma -> Spal won
# prediction was correct
# Spal: [26.12 -> 26.91] & [7.09 -> 6.01]
# Parma: [25 -> 24.07] & [8.33 -> 6.94]
# 3.16%---------------------------------------------
# Udinese vs Sampdoria -> Udinese won
# prediciton was wrong
# Udinese: [25 -> 26.16] & [8.33 -> 6.76]
# Sampdoria: [25 -> 23.99] & [8.33 -> 6.84]
# 3.42%---------------------------------------------
# Draw
# 3.68%---------------------------------------------
# Genoa vs Empoli -> Genoa won
# prediciton was wrong
# Genoa: [25 -> 26.32] & [8.33 -> 6.75]
# Empoli: [26.03 -> 24.81] & [6.97 -> 5.66]
# 3.95%---------------------------------------------
# Draw
# 4.21%---------------------------------------------
# Fiorentina vs Chievo -> Fiorentina won
# prediction was correct
# Fiorentina: [25 -> 25.99] & [8.33 -> 7.02]
# Chievo: [23.08 -> 22.57] & [5.68 -> 5.06]
# 4.47%---------------------------------------------
# Draw
# 4.74%---------------------------------------------
# Draw
# 5.0%---------------------------------------------
# Milan vs Roma -> Milan won
# prediciton was wrong
# Milan: [24.05 -> 25.42] & [6.77 -> 5.74]
# Roma: [26.24 -> 24.85] & [6.66 -> 5.35]
# 5.26%---------------------------------------------
# Bologna vs Inter -> Inter won
# prediction was correct
# Bologna: [23.82 -> 22.86] & [6.95 -> 5.95]
# Inter: [23.86 -> 24.88] & [6.79 -> 5.86]
# 5.53%---------------------------------------------
# Parma vs Juventus -> Juventus won
# prediction was correct
# Parma: [24.07 -> 23.4] & [6.94 -> 6.27]
# Juventus: [27.28 -> 27.74] & [5.15 -> 4.64]
# 5.79%---------------------------------------------
# Fiorentina vs Udinese -> Fiorentina won
# prediciton was wrong
# Fiorentina: [25.99 -> 27.07] & [7.02 -> 5.91]
# Udinese: [26.16 -> 25.14] & [6.76 -> 5.59]
# 6.05%---------------------------------------------
# Torino vs Spal -> Torino won
# prediciton was wrong
# Torino: [23.79 -> 25.52] & [7.01 -> 5.36]
# Spal: [26.91 -> 25.57] & [6.01 -> 5.14]
# 6.32%---------------------------------------------
# Sassuolo vs Genoa -> Sassuolo won
# prediciton was wrong
# Sassuolo: [26.2 -> 27.33] & [6.98 -> 5.92]
# Genoa: [26.32 -> 25.31] & [6.75 -> 5.71]
# 6.58%---------------------------------------------
# Sampdoria vs Napoli -> Sampdoria won
# prediciton was wrong
# Sampdoria: [23.99 -> 25.89] & [6.84 -> 5.34]
# Napoli: [27.59 -> 26.16] & [5.64 -> 4.72]
# 6.84%---------------------------------------------
# Lazio vs Frosinone -> Lazio won
# prediciton was wrong
# Lazio: [22.59 -> 23.64] & [5.34 -> 4.54]
# Frosinone: [23.77 -> 22.46] & [6.89 -> 5.76]
# 7.11%---------------------------------------------
# Draw
# 7.37%---------------------------------------------
# Atalanta vs Cagliari -> Cagliari won
# prediciton was wrong
# Atalanta: [26.27 -> 24.68] & [6.89 -> 5.91]
# Cagliari: [24.0 -> 25.42] & [6.69 -> 5.59]
# 7.63%---------------------------------------------
# Inter vs Parma -> Parma won
# prediciton was wrong
# Inter: [24.88 -> 23.63] & [5.86 -> 4.91]
# Parma: [23.4 -> 24.69] & [6.27 -> 5.14]
# 7.89%---------------------------------------------
# Napoli vs Fiorentina -> Napoli won
# prediciton was wrong
# Napoli: [26.16 -> 27.03] & [4.72 -> 4.08]
# Fiorentina: [27.07 -> 25.87] & [5.91 -> 5.0]
# 8.16%---------------------------------------------
# Frosinone vs Sampdoria -> Sampdoria won
# prediction was correct
# Frosinone: [22.46 -> 22.13] & [5.76 -> 4.82]
# Sampdoria: [25.89 -> 26.3] & [5.34 -> 4.63]
# 8.42%---------------------------------------------
# Draw
# 8.68%---------------------------------------------
# Draw
# 8.95%---------------------------------------------
# Juventus vs Sassuolo -> Juventus won
# prediction was correct
# Juventus: [27.74 -> 28.45] & [4.64 -> 3.84]
# Sassuolo: [27.33 -> 26.4] & [5.92 -> 5.03]
# 9.21%---------------------------------------------
# Genoa vs Bologna -> Genoa won
# prediction was correct
# Genoa: [25.31 -> 25.83] & [5.71 -> 4.98]
# Bologna: [22.86 -> 22.25] & [5.95 -> 5.14]
# 9.47%---------------------------------------------
# Empoli vs Lazio -> Lazio won
# prediciton was wrong
# Empoli: [24.81 -> 23.59] & [5.66 -> 4.7]
# Lazio: [23.64 -> 24.69] & [4.54 -> 4.06]
# 9.74%---------------------------------------------
# Draw
# 10.0%---------------------------------------------
# Spal vs Atalanta -> Spal won
# prediction was correct
# Spal: [25.57 -> 26.28] & [5.14 -> 4.34]
# Atalanta: [24.68 -> 23.82] & [5.91 -> 4.93]
# 10.26%---------------------------------------------
# Draw
# 10.53%---------------------------------------------
# Sassuolo vs Empoli -> Sassuolo won
# prediction was correct
# Sassuolo: [26.4 -> 26.96] & [5.03 -> 4.47]
# Empoli: [23.59 -> 23.05] & [4.7 -> 4.32]
# 10.79%---------------------------------------------
# Parma vs Cagliari -> Parma won
# prediciton was wrong
# Parma: [24.69 -> 25.77] & [5.14 -> 4.31]
# Cagliari: [25.42 -> 24.28] & [5.59 -> 4.47]
# 11.05%---------------------------------------------
# Fiorentina vs Spal -> Fiorentina won
# prediciton was wrong
# Fiorentina: [25.87 -> 26.98] & [5.0 -> 4.16]
# Spal: [26.28 -> 25.41] & [4.34 -> 3.77]
# 11.32%---------------------------------------------
# Sampdoria vs Inter -> Inter won
# prediciton was wrong
# Sampdoria: [26.3 -> 24.99] & [4.63 -> 3.9]
# Inter: [23.63 -> 25.02] & [4.91 -> 4.19]
# 11.58%---------------------------------------------
# Torino vs Napoli -> Napoli won
# prediction was correct
# Torino: [25.52 -> 24.74] & [5.36 -> 4.64]
# Napoli: [27.03 -> 27.67] & [4.08 -> 3.57]
# 11.84%---------------------------------------------
# Lazio vs Genoa -> Lazio won
# prediciton was wrong
# Lazio: [24.69 -> 25.63] & [4.06 -> 3.56]
# Genoa: [25.83 -> 24.73] & [4.98 -> 4.14]
# 12.11%---------------------------------------------
# Chievo vs Udinese -> Udinese won
# prediction was correct
# Chievo: [22.57 -> 22.1] & [5.06 -> 4.38]
# Udinese: [25.14 -> 25.74] & [5.59 -> 5.21]
# 12.37%---------------------------------------------
# Bologna vs Roma -> Bologna won
# prediciton was wrong
# Bologna: [22.25 -> 23.5] & [5.14 -> 4.21]
# Roma: [24.85 -> 23.41] & [5.35 -> 4.24]
# 12.63%---------------------------------------------
# Draw
# 12.89%---------------------------------------------
# Frosinone vs Juventus -> Juventus won
# prediction was correct
# Frosinone: [22.13 -> 21.95] & [4.82 -> 4.56]
# Juventus: [28.45 -> 28.54] & [3.84 -> 3.6]
# 13.16%---------------------------------------------
# Inter vs Fiorentina -> Inter won
# prediciton was wrong
# Inter: [25.02 -> 26.16] & [4.19 -> 3.47]
# Fiorentina: [26.98 -> 25.91] & [4.16 -> 3.41]
# 13.42%---------------------------------------------
# Udinese vs Lazio -> Lazio won
# prediciton was wrong
# Udinese: [25.74 -> 24.73] & [5.21 -> 4.47]
# Lazio: [25.63 -> 26.32] & [3.56 -> 3.05]
# 13.68%---------------------------------------------
# Roma vs Frosinone -> Roma won
# prediction was correct
# Roma: [23.41 -> 23.99] & [4.24 -> 3.83]
# Frosinone: [21.95 -> 21.37] & [4.56 -> 3.75]
# 13.95%---------------------------------------------
# Napoli vs Parma -> Napoli won
# prediction was correct
# Napoli: [27.67 -> 28.18] & [3.57 -> 3.22]
# Parma: [25.77 -> 25.27] & [4.31 -> 3.74]
# 14.21%---------------------------------------------
# Juventus vs Bologna -> Juventus won
# prediction was correct
# Juventus: [28.54 -> 28.64] & [3.6 -> 3.45]
# Bologna: [23.5 -> 23.24] & [4.21 -> 3.88]
# 14.47%---------------------------------------------
# Genoa vs Chievo -> Genoa won
# prediction was correct
# Genoa: [24.73 -> 25.19] & [4.14 -> 3.84]
# Chievo: [22.1 -> 21.59] & [4.38 -> 3.88]
# 14.74%---------------------------------------------
# Draw
# 15.0%---------------------------------------------
# Draw
# 15.26%---------------------------------------------
# Spal vs Sassuolo -> Sassuolo won
# prediction was correct
# Spal: [25.41 -> 24.9] & [3.77 -> 3.25]
# Sassuolo: [26.96 -> 27.64] & [4.47 -> 3.87]
# 15.53%---------------------------------------------
# Draw
# 15.79%---------------------------------------------
# Roma vs Lazio -> Roma won
# prediciton was wrong
# Roma: [23.99 -> 25.23] & [3.83 -> 3.23]
# Lazio: [26.32 -> 25.26] & [3.05 -> 2.61]
# 16.05%---------------------------------------------
# Juventus vs Napoli -> Juventus won
# prediction was correct
# Juventus: [28.64 -> 29.4] & [3.45 -> 2.95]
# Napoli: [28.18 -> 27.56] & [3.22 -> 2.7]
# 16.32%---------------------------------------------
# Inter vs Cagliari -> Inter won
# prediction was correct
# Inter: [26.16 -> 26.61] & [3.47 -> 2.88]
# Cagliari: [24.28 -> 23.69] & [4.47 -> 3.84]
# 16.58%---------------------------------------------
# Bologna vs Udinese -> Bologna won
# prediciton was wrong
# Bologna: [23.24 -> 24.21] & [3.88 -> 3.34]
# Udinese: [24.73 -> 23.54] & [4.47 -> 3.68]
# 16.84%---------------------------------------------
# Frosinone vs Genoa -> Genoa won
# prediction was correct
# Frosinone: [21.37 -> 21.11] & [3.75 -> 3.52]
# Genoa: [25.19 -> 25.49] & [3.84 -> 3.63]
# 17.11%---------------------------------------------
# Fiorentina vs Atalanta -> Fiorentina won
# prediction was correct
# Fiorentina: [25.91 -> 26.27] & [3.41 -> 2.85]
# Atalanta: [23.82 -> 23.24] & [4.93 -> 4.05]
# 17.37%---------------------------------------------
# Chievo vs Torino -> Torino won
# prediction was correct
# Chievo: [21.59 -> 21.28] & [3.88 -> 3.4]
# Torino: [24.74 -> 25.16] & [4.64 -> 4.14]
# 17.63%---------------------------------------------
# Parma vs Empoli -> Parma won
# prediction was correct
# Parma: [25.27 -> 25.71] & [3.74 -> 3.31]
# Empoli: [23.05 -> 22.47] & [4.32 -> 3.75]
# 17.89%---------------------------------------------
# Sassuolo vs Milan -> Milan won
# prediciton was wrong
# Sassuolo: [27.64 -> 26.59] & [3.87 -> 3.35]
# Milan: [25.42 -> 26.91] & [5.74 -> 4.31]
# 18.16%---------------------------------------------
# Sampdoria vs Spal -> Sampdoria won
# prediction was correct
# Sampdoria: [24.99 -> 25.87] & [3.9 -> 3.61]
# Spal: [24.9 -> 24.21] & [3.25 -> 2.73]
# 18.42%---------------------------------------------
# Torino vs Frosinone -> Torino won
# prediction was correct
# Torino: [25.16 -> 25.46] & [4.14 -> 3.66]
# Frosinone: [21.11 -> 20.8] & [3.52 -> 3.11]
# 18.68%---------------------------------------------
# Cagliari vs Bologna -> Cagliari won
# prediciton was wrong
# Cagliari: [23.69 -> 24.63] & [3.84 -> 3.06]
# Bologna: [24.21 -> 23.46] & [3.34 -> 2.7]
# 18.95%---------------------------------------------
# Udinese vs Juventus -> Juventus won
# prediction was correct
# Udinese: [23.54 -> 23.53] & [3.68 -> 3.5]
# Juventus: [29.4 -> 29.45] & [2.95 -> 2.76]
# 19.21%---------------------------------------------
# Empoli vs Roma -> Roma won
# prediction was correct
# Empoli: [22.47 -> 21.99] & [3.75 -> 3.39]
# Roma: [25.23 -> 25.64] & [3.23 -> 2.96]
# 19.47%---------------------------------------------
# Genoa vs Parma -> Parma won
# prediction was correct
# Genoa: [25.49 -> 24.76] & [3.63 -> 2.9]
# Parma: [25.71 -> 26.39] & [3.31 -> 2.92]
# 19.74%---------------------------------------------
# Milan vs Chievo -> Milan won
# prediction was correct
# Milan: [26.91 -> 27.02] & [4.31 -> 4.35]
# Chievo: [21.28 -> 21.05] & [3.4 -> 3.24]
# 20.0%---------------------------------------------
# Lazio vs Fiorentina -> Lazio won
# prediciton was wrong
# Lazio: [25.26 -> 26.06] & [2.61 -> 2.16]
# Fiorentina: [26.27 -> 25.38] & [2.85 -> 2.45]
# 20.26%---------------------------------------------
# Atalanta vs Sampdoria -> Sampdoria won
# prediction was correct
# Atalanta: [23.24 -> 22.8] & [4.05 -> 3.47]
# Sampdoria: [25.87 -> 26.26] & [3.61 -> 3.13]
# 20.53%---------------------------------------------
# Napoli vs Sassuolo -> Napoli won
# prediction was correct
# Napoli: [27.56 -> 28.01] & [2.7 -> 2.39]
# Sassuolo: [26.59 -> 25.94] & [3.35 -> 2.84]
# 20.79%---------------------------------------------
# Spal vs Inter -> Inter won
# prediction was correct
# Spal: [24.21 -> 23.91] & [2.73 -> 2.35]
# Inter: [26.61 -> 26.97] & [2.88 -> 2.6]
# 21.05%---------------------------------------------
# Roma vs Spal -> Spal won
# prediciton was wrong
# Roma: [25.64 -> 24.56] & [2.96 -> 2.42]
# Spal: [23.91 -> 24.77] & [2.35 -> 1.95]
# 21.32%---------------------------------------------
# Draw
# 21.58%---------------------------------------------
# Udinese vs Napoli -> Napoli won
# prediction was correct
# Udinese: [23.53 -> 23.28] & [3.5 -> 3.21]
# Napoli: [28.01 -> 28.13] & [2.39 -> 2.28]
# 21.84%---------------------------------------------
# Draw
# 22.11%---------------------------------------------
# Parma vs Lazio -> Lazio won
# prediciton was wrong
# Parma: [26.39 -> 25.64] & [2.92 -> 2.44]
# Lazio: [26.06 -> 26.64] & [2.16 -> 1.8]
# 22.37%---------------------------------------------
# Chievo vs Atalanta -> Atalanta won
# prediction was correct
# Chievo: [21.05 -> 20.59] & [3.24 -> 2.79]
# Atalanta: [22.8 -> 23.35] & [3.47 -> 3.05]
# 22.63%---------------------------------------------
# Draw
# 22.89%---------------------------------------------
# Draw
# 23.16%---------------------------------------------
# Inter vs Milan -> Inter won
# prediciton was wrong
# Inter: [26.97 -> 27.47] & [2.6 -> 2.28]
# Milan: [27.02 -> 26.14] & [4.35 -> 3.53]
# 23.42%---------------------------------------------
# Draw
# 23.68%---------------------------------------------
# Atalanta vs Parma -> Atalanta won
# prediciton was wrong
# Atalanta: [23.35 -> 24.52] & [3.05 -> 2.39]
# Parma: [25.64 -> 24.66] & [2.44 -> 1.98]
# 23.95%---------------------------------------------
# Empoli vs Juventus -> Juventus won
# prediction was correct
# Empoli: [21.99 -> 21.98] & [3.39 -> 3.48]
# Juventus: [29.45 -> 29.51] & [2.76 -> 2.58]
# 24.21%---------------------------------------------
# Draw
# 24.47%---------------------------------------------
# Draw
# 24.74%---------------------------------------------
# Spal vs Frosinone -> Frosinone won
# prediciton was wrong
# Spal: [24.77 -> 23.73] & [1.95 -> 1.59]
# Frosinone: [20.8 -> 22.45] & [3.11 -> 2.39]
# 25.0%---------------------------------------------
# Draw
# 25.26%---------------------------------------------
# Cagliari vs Chievo -> Cagliari won
# prediction was correct
# Cagliari: [24.63 -> 24.78] & [3.06 -> 2.69]
# Chievo: [20.59 -> 20.46] & [2.79 -> 2.59]
# 25.53%---------------------------------------------
# Milan vs Sampdoria -> Milan won
# prediciton was wrong
# Milan: [26.14 -> 26.97] & [3.53 -> 3.0]
# Sampdoria: [26.26 -> 25.62] & [3.13 -> 2.6]
# 25.79%---------------------------------------------
# Draw
# 26.05%---------------------------------------------
# Lazio vs Inter -> Inter won
# prediction was correct
# Lazio: [26.64 -> 26.33] & [1.8 -> 1.54]
# Inter: [27.47 -> 27.95] & [2.28 -> 1.95]
# 26.32%---------------------------------------------
# Milan vs Genoa -> Milan won
# prediction was correct
# Milan: [26.97 -> 27.4] & [3.0 -> 2.6]
# Genoa: [24.76 -> 24.41] & [2.9 -> 2.55]
# 26.58%---------------------------------------------
# Napoli vs Empoli -> Napoli won
# prediction was correct
# Napoli: [28.13 -> 28.16] & [2.28 -> 2.22]
# Empoli: [21.98 -> 21.9] & [3.48 -> 3.41]
# 26.84%---------------------------------------------
# Inter vs Genoa -> Inter won
# prediction was correct
# Inter: [27.95 -> 28.1] & [1.95 -> 1.9]
# Genoa: [24.41 -> 24.19] & [2.55 -> 2.42]
# 27.11%---------------------------------------------
# Draw
# 27.37%---------------------------------------------
# Juventus vs Cagliari -> Juventus won
# prediction was correct
# Juventus: [29.51 -> 29.64] & [2.58 -> 2.33]
# Cagliari: [24.78 -> 24.69] & [2.69 -> 2.59]
# 27.63%---------------------------------------------
# Lazio vs Spal -> Lazio won
# prediction was correct
# Lazio: [26.33 -> 26.45] & [1.54 -> 1.45]
# Spal: [23.73 -> 23.54] & [1.59 -> 1.44]
# 27.89%---------------------------------------------
# Sampdoria vs Torino -> Torino won
# prediciton was wrong
# Sampdoria: [25.62 -> 24.99] & [2.6 -> 2.32]
# Torino: [25.46 -> 26.39] & [3.66 -> 3.04]
# 28.16%---------------------------------------------
# Draw
# 28.42%---------------------------------------------
# Chievo vs Sassuolo -> Sassuolo won
# prediction was correct
# Chievo: [20.46 -> 20.32] & [2.59 -> 2.56]
# Sassuolo: [25.94 -> 26.02] & [2.84 -> 2.65]
# 28.68%---------------------------------------------
# Bologna vs Atalanta -> Atalanta won
# prediction was correct
# Bologna: [23.46 -> 22.97] & [2.7 -> 2.19]
# Atalanta: [24.52 -> 24.94] & [2.39 -> 2.11]
# 28.95%---------------------------------------------
# Udinese vs Milan -> Milan won
# prediction was correct
# Udinese: [23.28 -> 23.03] & [3.21 -> 2.94]
# Milan: [27.4 -> 27.58] & [2.6 -> 2.39]
# 29.21%---------------------------------------------
# Draw
# 29.47%---------------------------------------------
# Torino vs Parma -> Parma won
# prediciton was wrong
# Torino: [26.39 -> 25.37] & [3.04 -> 2.21]
# Parma: [24.66 -> 25.39] & [1.98 -> 1.67]
# 29.74%---------------------------------------------
# Draw
# 30.0%---------------------------------------------
# Genoa vs Napoli -> Napoli won
# prediction was correct
# Genoa: [24.19 -> 23.99] & [2.42 -> 2.23]
# Napoli: [28.16 -> 28.33] & [2.22 -> 1.93]
# 30.26%---------------------------------------------
# Atalanta vs Inter -> Atalanta won
# prediciton was wrong
# Atalanta: [24.94 -> 26.17] & [2.11 -> 1.6]
# Inter: [28.1 -> 27.03] & [1.9 -> 1.66]
# 30.53%---------------------------------------------
# Roma vs Sampdoria -> Roma won
# prediciton was wrong
# Roma: [24.56 -> 25.23] & [2.42 -> 2.03]
# Sampdoria: [24.99 -> 24.32] & [2.32 -> 1.96]
# 30.79%---------------------------------------------
# Empoli vs Udinese -> Empoli won
# prediciton was wrong
# Empoli: [21.9 -> 22.87] & [3.41 -> 2.84]
# Udinese: [23.03 -> 22.24] & [2.94 -> 2.61]
# 31.05%---------------------------------------------
# Draw
# 31.32%---------------------------------------------
# Draw
# 31.58%---------------------------------------------
# Milan vs Juventus -> Juventus won
# prediction was correct
# Milan: [27.58 -> 27.22] & [2.39 -> 2.12]
# Juventus: [29.64 -> 29.96] & [2.33 -> 1.96]
# 31.84%---------------------------------------------
# Udinese vs Roma -> Udinese won
# prediciton was wrong
# Udinese: [22.24 -> 23.58] & [2.61 -> 2.01]
# Roma: [25.23 -> 24.24] & [2.03 -> 1.65]
# 32.11%---------------------------------------------
# Juventus vs Spal -> Juventus won
# prediction was correct
# Juventus: [29.96 -> 30.01] & [1.96 -> 1.93]
# Spal: [23.54 -> 23.47] & [1.44 -> 1.34]
# 32.37%---------------------------------------------
# Inter vs Frosinone -> Inter won
# prediction was correct
# Inter: [27.03 -> 27.06] & [1.66 -> 1.58]
# Frosinone: [22.45 -> 22.31] & [2.39 -> 2.04]
# 32.63%---------------------------------------------
# Parma vs Sassuolo -> Parma won
# prediciton was wrong
# Parma: [25.39 -> 25.9] & [1.67 -> 1.55]
# Sassuolo: [26.02 -> 25.19] & [2.65 -> 2.13]
# 32.89%---------------------------------------------
# Draw
# 33.16%---------------------------------------------
# Empoli vs Atalanta -> Empoli won
# prediciton was wrong
# Empoli: [22.87 -> 24.42] & [2.84 -> 2.17]
# Atalanta: [26.17 -> 25.28] & [1.6 -> 1.34]
# 33.42%---------------------------------------------
# Draw
# 33.68%---------------------------------------------
# Draw
# 33.95%---------------------------------------------
# Draw
# 34.21%---------------------------------------------
# Draw
# 34.47%---------------------------------------------
# Draw
# 34.74%---------------------------------------------
# Fiorentina vs Juventus -> Juventus won
# prediction was correct
# Fiorentina: [25.38 -> 25.29] & [2.45 -> 2.31]
# Juventus: [30.01 -> 30.12] & [1.93 -> 1.76]
# 35.0%---------------------------------------------
# Sampdoria vs Bologna -> Sampdoria won
# prediction was correct
# Sampdoria: [24.32 -> 24.7] & [1.96 -> 1.73]
# Bologna: [22.97 -> 22.58] & [2.19 -> 1.85]
# 35.26%---------------------------------------------
# Milan vs Parma -> Milan won
# prediction was correct
# Milan: [27.22 -> 27.63] & [2.12 -> 1.83]
# Parma: [25.9 -> 25.55] & [1.55 -> 1.37]
# 35.53%---------------------------------------------
# Torino vs Genoa -> Torino won
# prediction was correct
# Torino: [25.37 -> 25.76] & [2.21 -> 1.93]
# Genoa: [23.99 -> 23.64] & [2.23 -> 2.04]
# 35.79%---------------------------------------------
# Draw
# 36.05%---------------------------------------------
# Draw
# 36.32%---------------------------------------------
# Draw
# 36.58%---------------------------------------------
# Draw
# 36.84%---------------------------------------------
# Atalanta vs Napoli -> Napoli won
# prediction was correct
# Atalanta: [25.28 -> 25.16] & [1.34 -> 1.22]
# Napoli: [28.33 -> 28.52] & [1.93 -> 1.8]
# 37.11%---------------------------------------------
# Juventus vs Inter -> Juventus won
# prediction was correct
# Juventus: [30.12 -> 30.3] & [1.76 -> 1.52]
# Inter: [27.06 -> 26.94] & [1.58 -> 1.5]
# 37.37%---------------------------------------------
# Napoli vs Frosinone -> Napoli won
# prediction was correct
# Napoli: [28.52 -> 28.54] & [1.8 -> 1.73]
# Frosinone: [22.31 -> 22.27] & [2.04 -> 2.09]
# 37.63%---------------------------------------------
# Draw
# 37.89%---------------------------------------------
# Draw
# 38.16%---------------------------------------------
# Draw
# 38.42%---------------------------------------------
# Udinese vs Atalanta -> Atalanta won
# prediction was correct
# Udinese: [23.58 -> 23.25] & [2.01 -> 1.75]
# Atalanta: [25.16 -> 25.37] & [1.22 -> 1.17]
# 38.68%---------------------------------------------
# Draw
# 38.95%---------------------------------------------
# Empoli vs Bologna -> Empoli won
# prediction was correct
# Empoli: [24.42 -> 24.74] & [2.17 -> 1.86]
# Bologna: [22.58 -> 22.3] & [1.85 -> 1.62]
# 39.21%---------------------------------------------
# Draw
# 39.47%---------------------------------------------
# Draw
# 39.74%---------------------------------------------
# Inter vs Udinese -> Inter won
# prediction was correct
# Inter: [26.94 -> 27.01] & [1.5 -> 1.47]
# Udinese: [23.25 -> 23.12] & [1.75 -> 1.76]
# 40.0%---------------------------------------------
# Torino vs Juventus -> Juventus won
# prediction was correct
# Torino: [25.76 -> 25.74] & [1.93 -> 1.91]
# Juventus: [30.3 -> 30.29] & [1.52 -> 1.54]
# 40.26%---------------------------------------------
# Draw
# 40.53%---------------------------------------------
# Sampdoria vs Parma -> Sampdoria won
# prediciton was wrong
# Sampdoria: [24.7 -> 25.46] & [1.73 -> 1.37]
# Parma: [25.55 -> 25.0] & [1.37 -> 1.2]
# 40.79%---------------------------------------------
# Frosinone vs Sassuolo -> Sassuolo won
# prediction was correct
# Frosinone: [22.27 -> 22.06] & [2.09 -> 1.81]
# Sassuolo: [25.19 -> 25.37] & [2.13 -> 1.9]
# 41.05%---------------------------------------------
# Fiorentina vs Empoli -> Fiorentina won
# prediction was correct
# Fiorentina: [25.29 -> 25.85] & [2.31 -> 1.85]
# Empoli: [24.74 -> 24.37] & [1.86 -> 1.67]
# 41.32%---------------------------------------------
# Cagliari vs Napoli -> Napoli won
# prediction was correct
# Cagliari: [24.69 -> 24.47] & [2.59 -> 2.38]
# Napoli: [28.54 -> 28.64] & [1.73 -> 1.61]
# 41.58%---------------------------------------------
# Roma vs Genoa -> Roma won
# prediction was correct
# Roma: [24.24 -> 24.62] & [1.65 -> 1.42]
# Genoa: [23.64 -> 23.15] & [2.04 -> 1.71]
# 41.84%---------------------------------------------
# Atalanta vs Lazio -> Atalanta won
# prediciton was wrong
# Atalanta: [25.37 -> 25.93] & [1.17 -> 0.98]
# Lazio: [26.45 -> 25.72] & [1.45 -> 1.16]
# 42.11%---------------------------------------------
# Draw
# 42.37%---------------------------------------------
# Lazio vs Cagliari -> Lazio won
# prediction was correct
# Lazio: [25.72 -> 25.97] & [1.16 -> 1.05]
# Cagliari: [24.47 -> 24.0] & [2.38 -> 1.85]
# 42.63%---------------------------------------------
# Draw
# 42.89%---------------------------------------------
# Draw
# 43.16%---------------------------------------------
# Napoli vs Spal -> Napoli won
# prediction was correct
# Napoli: [28.64 -> 28.58] & [1.61 -> 1.56]
# Spal: [23.47 -> 23.45] & [1.34 -> 1.36]
# 43.42%---------------------------------------------
# Milan vs Fiorentina -> Fiorentina won
# prediciton was wrong
# Milan: [27.63 -> 26.78] & [1.83 -> 1.5]
# Fiorentina: [25.85 -> 26.72] & [1.85 -> 1.53]
# 43.68%---------------------------------------------
# Genoa vs Atalanta -> Genoa won
# prediciton was wrong
# Genoa: [23.15 -> 24.41] & [1.71 -> 1.32]
# Atalanta: [25.93 -> 25.22] & [0.98 -> 0.84]
# 43.95%---------------------------------------------
# Empoli vs Sampdoria -> Sampdoria won
# prediction was correct
# Empoli: [24.37 -> 23.99] & [1.67 -> 1.4]
# Sampdoria: [25.46 -> 25.74] & [1.37 -> 1.17]
# 44.21%---------------------------------------------
# Draw
# 44.47%---------------------------------------------
# Draw
# 44.74%---------------------------------------------
# Juventus vs Roma -> Juventus won
# prediction was correct
# Juventus: [30.29 -> 30.26] & [1.54 -> 1.55]
# Roma: [24.62 -> 24.56] & [1.42 -> 1.43]
# 45.0%---------------------------------------------
# Draw
# 45.26%---------------------------------------------
# Sampdoria vs Chievo -> Sampdoria won
# prediction was correct
# Sampdoria: [25.74 -> 25.76] & [1.17 -> 1.13]
# Chievo: [20.32 -> 20.36] & [2.56 -> 2.37]
# 45.53%---------------------------------------------
# Fiorentina vs Parma -> Parma won
# prediciton was wrong
# Fiorentina: [26.72 -> 25.83] & [1.53 -> 1.28]
# Parma: [25.0 -> 25.68] & [1.2 -> 0.96]
# 45.79%---------------------------------------------
# Cagliari vs Genoa -> Cagliari won
# prediciton was wrong
# Cagliari: [24.0 -> 24.64] & [1.85 -> 1.47]
# Genoa: [24.41 -> 23.94] & [1.32 -> 1.17]
# 46.05%---------------------------------------------
# Bologna vs Lazio -> Lazio won
# prediction was correct
# Bologna: [22.3 -> 22.21] & [1.62 -> 1.53]
# Lazio: [25.97 -> 26.02] & [1.05 -> 1.03]
# 46.32%---------------------------------------------
# Draw
# 46.58%---------------------------------------------
# Torino vs Empoli -> Torino won
# prediction was correct
# Torino: [25.74 -> 26.09] & [1.91 -> 1.7]
# Empoli: [23.99 -> 23.75] & [1.4 -> 1.3]
# 46.84%---------------------------------------------
# Draw
# 47.11%---------------------------------------------
# Roma vs Sassuolo -> Roma won
# prediciton was wrong
# Roma: [24.56 -> 25.14] & [1.43 -> 1.17]
# Sassuolo: [25.37 -> 24.65] & [1.9 -> 1.51]
# 47.37%---------------------------------------------
# Inter vs Napoli -> Inter won
# prediciton was wrong
# Inter: [27.01 -> 27.78] & [1.47 -> 1.21]
# Napoli: [28.58 -> 27.79] & [1.56 -> 1.22]
# 47.63%---------------------------------------------
# Juventus vs Sampdoria -> Juventus won
# prediction was correct
# Juventus: [30.26 -> 30.29] & [1.55 -> 1.52]
# Sampdoria: [25.76 -> 25.7] & [1.13 -> 1.11]
# 47.89%---------------------------------------------
# Udinese vs Cagliari -> Udinese won
# prediciton was wrong
# Udinese: [23.12 -> 24.0] & [1.76 -> 1.51]
# Cagliari: [24.64 -> 23.93] & [1.47 -> 1.29]
# 48.16%---------------------------------------------
# Sassuolo vs Atalanta -> Atalanta won
# prediction was correct
# Sassuolo: [24.65 -> 24.15] & [1.51 -> 1.27]
# Atalanta: [25.22 -> 25.47] & [0.84 -> 0.76]
# 48.42%---------------------------------------------
# Parma vs Roma -> Roma won
# prediciton was wrong
# Parma: [25.68 -> 25.24] & [0.96 -> 0.9]
# Roma: [25.14 -> 25.71] & [1.17 -> 0.92]
# 48.68%---------------------------------------------
# Draw
# 48.95%---------------------------------------------
# Draw
# 49.21%---------------------------------------------
# Empoli vs Inter -> Inter won
# prediction was correct
# Empoli: [23.75 -> 23.66] & [1.3 -> 1.31]
# Inter: [27.78 -> 27.84] & [1.21 -> 1.22]
# 49.47%---------------------------------------------
# Chievo vs Frosinone -> Chievo won
# prediciton was wrong
# Chievo: [20.36 -> 21.31] & [2.37 -> 1.88]
# Frosinone: [22.06 -> 21.29] & [1.81 -> 1.51]
# 49.74%---------------------------------------------
# Napoli vs Bologna -> Napoli won
# prediction was correct
# Napoli: [27.79 -> 27.83] & [1.22 -> 1.23]
# Bologna: [22.21 -> 22.15] & [1.53 -> 1.54]
# 50.0%---------------------------------------------
# Milan vs Spal -> Milan won
# prediction was correct
# Milan: [26.78 -> 26.91] & [1.5 -> 1.32]
# Spal: [23.45 -> 23.4] & [1.36 -> 1.24]
# 50.26%---------------------------------------------
# Roma vs Torino -> Roma won
# prediciton was wrong
# Roma: [25.71 -> 26.05] & [0.92 -> 0.77]
# Torino: [26.09 -> 25.46] & [1.7 -> 1.39]
# 50.53%---------------------------------------------
# Udinese vs Parma -> Parma won
# prediction was correct
# Udinese: [24.0 -> 23.68] & [1.51 -> 1.26]
# Parma: [25.24 -> 25.44] & [0.9 -> 0.86]
# 50.79%---------------------------------------------
# Draw
# 51.05%---------------------------------------------
# Frosinone vs Atalanta -> Atalanta won
# prediction was correct
# Frosinone: [21.29 -> 21.26] & [1.51 -> 1.49]
# Atalanta: [25.47 -> 25.48] & [0.76 -> 0.7]
# 51.32%---------------------------------------------
# Draw
# 51.58%---------------------------------------------
# Draw
# 51.84%---------------------------------------------
# Draw
# 52.11%---------------------------------------------
# Napoli vs Lazio -> Napoli won
# prediction was correct
# Napoli: [27.83 -> 28.03] & [1.23 -> 1.11]
# Lazio: [26.02 -> 25.89] & [1.03 -> 0.94]
# 52.37%---------------------------------------------
# Genoa vs Milan -> Milan won
# prediction was correct
# Genoa: [23.94 -> 23.85] & [1.17 -> 1.1]
# Milan: [26.91 -> 27.04] & [1.32 -> 1.21]
# 52.63%---------------------------------------------
# Juventus vs Chievo -> Juventus won
# prediction was correct
# Juventus: [30.29 -> 30.26] & [1.52 -> 1.64]
# Chievo: [21.31 -> 21.33] & [1.88 -> 1.82]
# 52.89%---------------------------------------------
# Sassuolo vs Cagliari -> Sassuolo won
# prediction was correct
# Sassuolo: [24.15 -> 24.58] & [1.27 -> 1.06]
# Cagliari: [23.93 -> 23.51] & [1.29 -> 1.14]
# 53.16%---------------------------------------------
# Sampdoria vs Udinese -> Sampdoria won
# prediction was correct
# Sampdoria: [25.7 -> 25.9] & [1.11 -> 0.98]
# Udinese: [23.68 -> 23.52] & [1.26 -> 1.14]
# 53.42%---------------------------------------------
# Draw
# 53.68%---------------------------------------------
# Chievo vs Fiorentina -> Fiorentina won
# prediction was correct
# Chievo: [21.33 -> 21.24] & [1.82 -> 1.72]
# Fiorentina: [25.83 -> 25.87] & [1.28 -> 1.24]
# 53.95%---------------------------------------------
# Parma vs Spal -> Spal won
# prediciton was wrong
# Parma: [25.44 -> 24.8] & [0.86 -> 0.7]
# Spal: [23.4 -> 24.31] & [1.24 -> 0.94]
# 54.21%---------------------------------------------
# Bologna vs Frosinone -> Frosinone won
# prediciton was wrong
# Bologna: [22.15 -> 21.54] & [1.54 -> 1.21]
# Frosinone: [21.26 -> 21.92] & [1.49 -> 1.19]
# 54.47%---------------------------------------------
# Draw
# 54.74%---------------------------------------------
# Torino vs Inter -> Torino won
# prediciton was wrong
# Torino: [25.46 -> 26.43] & [1.39 -> 1.11]
# Inter: [27.84 -> 27.0] & [1.22 -> 1.03]
# 55.0%---------------------------------------------
# Lazio vs Juventus -> Juventus won
# prediction was correct
# Lazio: [25.89 -> 25.86] & [0.94 -> 0.96]
# Juventus: [30.26 -> 30.36] & [1.64 -> 1.54]
# 55.26%---------------------------------------------
# Empoli vs Genoa -> Genoa won
# prediction was correct
# Empoli: [23.66 -> 23.22] & [1.31 -> 1.07]
# Genoa: [23.85 -> 24.2] & [1.1 -> 0.96]
# 55.53%---------------------------------------------
# Draw
# 55.79%---------------------------------------------
# Napoli vs Sampdoria -> Napoli won
# prediction was correct
# Napoli: [28.03 -> 28.2] & [1.11 -> 1.05]
# Sampdoria: [25.9 -> 25.77] & [0.98 -> 0.9]
# 56.05%---------------------------------------------
# Draw
# 56.32%---------------------------------------------
# Draw
# 56.58%---------------------------------------------
# Draw
# 56.84%---------------------------------------------
# Draw
# 57.11%---------------------------------------------
# Inter vs Bologna -> Bologna won
# prediciton was wrong
# Inter: [27.0 -> 25.62] & [1.03 -> 0.83]
# Bologna: [21.54 -> 23.22] & [1.21 -> 0.91]
# 57.37%---------------------------------------------
# Draw
# 57.63%---------------------------------------------
# Frosinone vs Lazio -> Lazio won
# prediction was correct
# Frosinone: [21.92 -> 21.85] & [1.19 -> 1.13]
# Lazio: [25.86 -> 25.9] & [0.96 -> 1.01]
# 57.89%---------------------------------------------
# Cagliari vs Atalanta -> Atalanta won
# prediction was correct
# Cagliari: [23.51 -> 23.32] & [1.14 -> 1.0]
# Atalanta: [25.48 -> 25.58] & [0.7 -> 0.65]
# 58.16%---------------------------------------------
# Lazio vs Empoli -> Lazio won
# prediction was correct
# Lazio: [25.9 -> 26.01] & [1.01 -> 0.96]
# Empoli: [23.22 -> 23.1] & [1.07 -> 0.99]
# 58.42%---------------------------------------------
# Chievo vs Roma -> Roma won
# prediction was correct
# Chievo: [21.24 -> 21.19] & [1.72 -> 1.66]
# Roma: [26.05 -> 26.06] & [0.77 -> 0.74]
# 58.68%---------------------------------------------
# Draw
# 58.95%---------------------------------------------
# Parma vs Inter -> Inter won
# prediction was correct
# Parma: [24.8 -> 24.6] & [0.7 -> 0.62]
# Inter: [25.62 -> 25.83] & [0.83 -> 0.71]
# 59.21%---------------------------------------------
# Draw
# 59.47%---------------------------------------------
# Torino vs Udinese -> Torino won
# prediction was correct
# Torino: [26.43 -> 26.55] & [1.11 -> 1.03]
# Udinese: [23.52 -> 23.41] & [1.14 -> 1.11]
# 59.74%---------------------------------------------
# Sampdoria vs Frosinone -> Frosinone won
# prediciton was wrong
# Sampdoria: [25.77 -> 24.77] & [0.9 -> 0.73]
# Frosinone: [21.85 -> 23.13] & [1.13 -> 0.82]
# 60.0%---------------------------------------------
# Atalanta vs Spal -> Atalanta won
# prediction was correct
# Atalanta: [25.58 -> 25.7] & [0.65 -> 0.61]
# Spal: [24.31 -> 24.1] & [0.94 -> 0.79]
# 60.26%---------------------------------------------
# Sassuolo vs Juventus -> Juventus won
# prediction was correct
# Sassuolo: [24.58 -> 24.6] & [1.06 -> 0.98]
# Juventus: [30.36 -> 30.25] & [1.54 -> 1.55]
# 60.53%---------------------------------------------
# Milan vs Cagliari -> Milan won
# prediction was correct
# Milan: [27.04 -> 27.1] & [1.21 -> 1.18]
# Cagliari: [23.32 -> 23.28] & [1.0 -> 0.97]
# 60.79%---------------------------------------------
# Juventus vs Frosinone -> Juventus won
# prediction was correct
# Juventus: [30.25 -> 30.24] & [1.55 -> 1.52]
# Frosinone: [23.13 -> 23.14] & [0.82 -> 0.84]
# 61.05%---------------------------------------------
# Cagliari vs Parma -> Cagliari won
# prediciton was wrong
# Cagliari: [23.28 -> 24.0] & [0.97 -> 0.75]
# Parma: [24.6 -> 24.13] & [0.62 -> 0.53]
# 61.32%---------------------------------------------
# Atalanta vs Milan -> Milan won
# prediction was correct
# Atalanta: [25.7 -> 25.54] & [0.61 -> 0.58]
# Milan: [27.1 -> 27.35] & [1.18 -> 1.01]
# 61.58%---------------------------------------------
# Spal vs Fiorentina -> Fiorentina won
# prediction was correct
# Spal: [24.1 -> 24.0] & [0.79 -> 0.72]
# Fiorentina: [25.87 -> 26.08] & [1.24 -> 1.05]
# 61.84%---------------------------------------------
# Udinese vs Chievo -> Udinese won
# prediction was correct
# Udinese: [23.41 -> 23.54] & [1.11 -> 0.97]
# Chievo: [21.19 -> 21.01] & [1.66 -> 1.49]
# 62.11%---------------------------------------------
# Genoa vs Lazio -> Genoa won
# prediciton was wrong
# Genoa: [24.2 -> 24.9] & [0.96 -> 0.75]
# Lazio: [26.01 -> 25.3] & [0.96 -> 0.76]
# 62.37%---------------------------------------------
# Empoli vs Sassuolo -> Empoli won
# prediciton was wrong
# Empoli: [23.1 -> 23.79] & [0.99 -> 0.82]
# Sassuolo: [24.6 -> 23.93] & [0.98 -> 0.81]
# 62.63%---------------------------------------------
# Inter vs Sampdoria -> Inter won
# prediction was correct
# Inter: [25.83 -> 26.02] & [0.71 -> 0.64]
# Sampdoria: [24.77 -> 24.61] & [0.73 -> 0.67]
# 62.89%---------------------------------------------
# Draw
# 63.16%---------------------------------------------
# Roma vs Bologna -> Roma won
# prediction was correct
# Roma: [26.06 -> 26.12] & [0.74 -> 0.76]
# Bologna: [23.22 -> 23.19] & [0.91 -> 0.81]
# 63.42%---------------------------------------------
# Milan vs Empoli -> Milan won
# prediction was correct
# Milan: [27.35 -> 27.35] & [1.01 -> 0.95]
# Empoli: [23.79 -> 23.74] & [0.82 -> 0.81]
# 63.68%---------------------------------------------
# Torino vs Atalanta -> Torino won
# prediction was correct
# Torino: [26.55 -> 26.8] & [1.03 -> 0.85]
# Atalanta: [25.54 -> 25.43] & [0.58 -> 0.52]
# 63.95%---------------------------------------------
# Frosinone vs Roma -> Roma won
# prediction was correct
# Frosinone: [23.14 -> 23.14] & [0.84 -> 0.75]
# Roma: [26.12 -> 26.19] & [0.76 -> 0.72]
# 64.21%---------------------------------------------
# Sampdoria vs Cagliari -> Sampdoria won
# prediction was correct
# Sampdoria: [24.61 -> 24.84] & [0.67 -> 0.58]
# Cagliari: [24.0 -> 23.73] & [0.75 -> 0.65]
# 64.47%---------------------------------------------
# Draw
# 64.74%---------------------------------------------
# Draw
# 65.0%---------------------------------------------
# Bologna vs Juventus -> Juventus won
# prediction was correct
# Bologna: [23.19 -> 23.18] & [0.81 -> 0.83]
# Juventus: [30.24 -> 30.23] & [1.52 -> 1.63]
# 65.26%---------------------------------------------
# Parma vs Napoli -> Napoli won
# prediction was correct
# Parma: [24.13 -> 24.14] & [0.53 -> 0.49]
# Napoli: [28.2 -> 28.22] & [1.05 -> 1.05]
# 65.53%---------------------------------------------
# Draw
# 65.79%---------------------------------------------
# Cagliari vs Inter -> Cagliari won
# prediciton was wrong
# Cagliari: [23.73 -> 24.49] & [0.65 -> 0.5]
# Inter: [26.02 -> 25.28] & [0.64 -> 0.51]
# 66.05%---------------------------------------------
# Draw
# 66.32%---------------------------------------------
# Milan vs Sassuolo -> Milan won
# prediction was correct
# Milan: [27.35 -> 27.39] & [0.95 -> 0.93]
# Sassuolo: [23.93 -> 23.87] & [0.81 -> 0.76]
# 66.58%---------------------------------------------
# Lazio vs Roma -> Lazio won
# prediciton was wrong
# Lazio: [25.3 -> 25.81] & [0.76 -> 0.64]
# Roma: [26.19 -> 25.72] & [0.72 -> 0.59]
# 66.84%---------------------------------------------
# Torino vs Chievo -> Torino won
# prediction was correct
# Torino: [26.8 -> 26.78] & [0.85 -> 0.82]
# Chievo: [21.01 -> 21.06] & [1.49 -> 1.52]
# 67.11%---------------------------------------------
# Udinese vs Bologna -> Udinese won
# prediction was correct
# Udinese: [23.54 -> 23.88] & [0.97 -> 0.82]
# Bologna: [23.18 -> 22.88] & [0.83 -> 0.77]
# 67.37%---------------------------------------------
# Spal vs Sampdoria -> Sampdoria won
# prediction was correct
# Spal: [24.0 -> 23.75] & [0.72 -> 0.61]
# Sampdoria: [24.84 -> 25.05] & [0.58 -> 0.49]
# 67.63%---------------------------------------------
# Draw
# 67.89%---------------------------------------------
# Atalanta vs Fiorentina -> Atalanta won
# prediciton was wrong
# Atalanta: [25.43 -> 25.74] & [0.52 -> 0.46]
# Fiorentina: [26.08 -> 25.46] & [1.05 -> 0.78]
# 68.16%---------------------------------------------
# Napoli vs Juventus -> Juventus won
# prediction was correct
# Napoli: [28.22 -> 28.09] & [1.05 -> 0.92]
# Juventus: [30.23 -> 30.53] & [1.63 -> 1.43]
# 68.42%---------------------------------------------
# Juventus vs Udinese -> Juventus won
# prediction was correct
# Juventus: [30.53 -> 30.57] & [1.43 -> 1.4]
# Udinese: [23.88 -> 23.87] & [0.82 -> 0.85]
# 68.68%---------------------------------------------
# Parma vs Genoa -> Parma won
# prediciton was wrong
# Parma: [24.14 -> 24.48] & [0.49 -> 0.4]
# Genoa: [24.9 -> 24.38] & [0.75 -> 0.58]
# 68.95%---------------------------------------------
# Chievo vs Milan -> Milan won
# prediction was correct
# Chievo: [21.06 -> 21.0] & [1.52 -> 1.45]
# Milan: [27.39 -> 27.39] & [0.93 -> 0.98]
# 69.21%---------------------------------------------
# Bologna vs Cagliari -> Bologna won
# prediciton was wrong
# Bologna: [22.88 -> 23.61] & [0.77 -> 0.55]
# Cagliari: [24.49 -> 24.02] & [0.5 -> 0.44]
# 69.47%---------------------------------------------
# Sampdoria vs Atalanta -> Atalanta won
# prediction was correct
# Sampdoria: [25.05 -> 24.86] & [0.49 -> 0.42]
# Atalanta: [25.74 -> 25.93] & [0.46 -> 0.4]
# 69.74%---------------------------------------------
# Inter vs Spal -> Inter won
# prediction was correct
# Inter: [25.28 -> 25.36] & [0.51 -> 0.52]
# Spal: [23.75 -> 23.62] & [0.61 -> 0.58]
# 70.0%---------------------------------------------
# Frosinone vs Torino -> Torino won
# prediction was correct
# Frosinone: [23.14 -> 23.13] & [0.75 -> 0.73]
# Torino: [26.78 -> 26.81] & [0.82 -> 0.81]
# 70.26%---------------------------------------------
# Draw
# 70.53%---------------------------------------------
# Draw
# 70.79%---------------------------------------------
# Roma vs Empoli -> Roma won
# prediction was correct
# Roma: [25.72 -> 25.78] & [0.59 -> 0.57]
# Empoli: [23.74 -> 23.64] & [0.81 -> 0.71]
# 71.05%---------------------------------------------
# Cagliari vs Fiorentina -> Cagliari won
# prediciton was wrong
# Cagliari: [24.02 -> 24.44] & [0.44 -> 0.38]
# Fiorentina: [25.46 -> 24.73] & [0.78 -> 0.59]
# 71.32%---------------------------------------------
# Sassuolo vs Sampdoria -> Sampdoria won
# prediction was correct
# Sassuolo: [23.87 -> 23.64] & [0.76 -> 0.64]
# Sampdoria: [24.86 -> 24.98] & [0.42 -> 0.38]
# 71.58%---------------------------------------------
# Spal vs Roma -> Spal won
# prediciton was wrong
# Spal: [23.62 -> 24.36] & [0.58 -> 0.48]
# Roma: [25.78 -> 25.06] & [0.57 -> 0.46]
# 71.84%---------------------------------------------
# Torino vs Bologna -> Bologna won
# prediciton was wrong
# Torino: [26.81 -> 25.65] & [0.81 -> 0.61]
# Bologna: [23.61 -> 24.38] & [0.55 -> 0.44]
# 72.11%---------------------------------------------
# Genoa vs Juventus -> Genoa won
# prediciton was wrong
# Genoa: [24.38 -> 25.39] & [0.58 -> 0.48]
# Juventus: [30.57 -> 28.19] & [1.4 -> 0.96]
# 72.37%---------------------------------------------
# Lazio vs Parma -> Lazio won
# prediction was correct
# Lazio: [25.81 -> 25.93] & [0.64 -> 0.58]
# Parma: [24.48 -> 24.42] & [0.4 -> 0.37]
# 72.63%---------------------------------------------
# Empoli vs Frosinone -> Empoli won
# prediction was correct
# Empoli: [23.64 -> 23.95] & [0.71 -> 0.66]
# Frosinone: [23.13 -> 22.88] & [0.73 -> 0.65]
# 72.89%---------------------------------------------
# Draw
# 73.16%---------------------------------------------
# Napoli vs Udinese -> Napoli won
# prediction was correct
# Napoli: [28.09 -> 28.08] & [0.92 -> 0.9]
# Udinese: [23.87 -> 23.83] & [0.85 -> 0.81]
# 73.42%---------------------------------------------
# Milan vs Inter -> Inter won
# prediciton was wrong
# Milan: [27.39 -> 26.44] & [0.98 -> 0.69]
# Inter: [25.36 -> 25.88] & [0.52 -> 0.42]
# 73.68%---------------------------------------------
# Chievo vs Cagliari -> Cagliari won
# prediction was correct
# Chievo: [21.0 -> 20.94] & [1.45 -> 1.36]
# Cagliari: [24.44 -> 24.46] & [0.38 -> 0.37]
# 73.95%---------------------------------------------
# Udinese vs Genoa -> Udinese won
# prediciton was wrong
# Udinese: [23.83 -> 24.55] & [0.81 -> 0.61]
# Genoa: [25.39 -> 24.92] & [0.48 -> 0.42]
# 74.21%---------------------------------------------
# Juventus vs Empoli -> Juventus won
# prediction was correct
# Juventus: [28.19 -> 28.24] & [0.96 -> 0.95]
# Empoli: [23.95 -> 23.9] & [0.66 -> 0.65]
# 74.47%---------------------------------------------
# Sampdoria vs Milan -> Sampdoria won
# prediciton was wrong
# Sampdoria: [24.98 -> 25.36] & [0.38 -> 0.34]
# Milan: [26.44 -> 25.71] & [0.69 -> 0.5]
# 74.74%---------------------------------------------
# Parma vs Atalanta -> Atalanta won
# prediction was correct
# Parma: [24.42 -> 24.35] & [0.37 -> 0.34]
# Atalanta: [25.93 -> 26.03] & [0.4 -> 0.35]
# 75.0%---------------------------------------------
# Roma vs Napoli -> Napoli won
# prediction was correct
# Roma: [25.06 -> 25.06] & [0.46 -> 0.46]
# Napoli: [28.08 -> 28.13] & [0.9 -> 0.85]
# 75.26%---------------------------------------------
# Frosinone vs Spal -> Spal won
# prediction was correct
# Frosinone: [22.88 -> 22.74] & [0.65 -> 0.59]
# Spal: [24.36 -> 24.48] & [0.48 -> 0.44]
# 75.53%---------------------------------------------
# Draw
# 75.79%---------------------------------------------
# Bologna vs Sassuolo -> Bologna won
# prediction was correct
# Bologna: [24.38 -> 24.54] & [0.44 -> 0.4]
# Sassuolo: [23.64 -> 23.41] & [0.64 -> 0.54]
# 76.05%---------------------------------------------
# Inter vs Lazio -> Lazio won
# prediction was correct
# Inter: [25.88 -> 25.66] & [0.42 -> 0.35]
# Lazio: [25.93 -> 26.22] & [0.58 -> 0.45]
# 76.32%---------------------------------------------
# Draw
# 76.58%---------------------------------------------
# Cagliari vs Juventus -> Juventus won
# prediction was correct
# Cagliari: [24.46 -> 24.42] & [0.37 -> 0.34]
# Juventus: [28.24 -> 28.25] & [0.95 -> 0.93]
# 76.84%---------------------------------------------
# Empoli vs Napoli -> Empoli won
# prediciton was wrong
# Empoli: [23.9 -> 24.92] & [0.65 -> 0.54]
# Napoli: [28.13 -> 26.75] & [0.85 -> 0.62]
# 77.11%---------------------------------------------
# Torino vs Sampdoria -> Torino won
# prediction was correct
# Torino: [25.65 -> 25.94] & [0.61 -> 0.53]
# Sampdoria: [25.36 -> 25.18] & [0.34 -> 0.29]
# 77.37%---------------------------------------------
# Spal vs Lazio -> Spal won
# prediciton was wrong
# Spal: [24.48 -> 25.04] & [0.44 -> 0.35]
# Lazio: [26.22 -> 25.61] & [0.45 -> 0.35]
# 77.63%---------------------------------------------
# Draw
# 77.89%---------------------------------------------
# Genoa vs Inter -> Inter won
# prediction was correct
# Genoa: [24.92 -> 24.79] & [0.42 -> 0.37]
# Inter: [25.66 -> 25.77] & [0.35 -> 0.3]
# 78.16%---------------------------------------------
# Frosinone vs Parma -> Frosinone won
# prediciton was wrong
# Frosinone: [22.74 -> 23.46] & [0.59 -> 0.42]
# Parma: [24.35 -> 23.95] & [0.34 -> 0.29]
# 78.42%---------------------------------------------
# Sassuolo vs Chievo -> Sassuolo won
# prediction was correct
# Sassuolo: [23.41 -> 23.42] & [0.54 -> 0.5]
# Chievo: [20.94 -> 20.82] & [1.36 -> 1.13]
# 78.68%---------------------------------------------
# Atalanta vs Bologna -> Atalanta won
# prediction was correct
# Atalanta: [26.03 -> 26.07] & [0.35 -> 0.32]
# Bologna: [24.54 -> 24.47] & [0.4 -> 0.35]
# 78.95%---------------------------------------------
# Draw
# 79.21%---------------------------------------------
# Juventus vs Milan -> Juventus won
# prediction was correct
# Juventus: [28.25 -> 28.31] & [0.93 -> 0.87]
# Milan: [25.71 -> 25.66] & [0.5 -> 0.47]
# 79.47%---------------------------------------------
# Sampdoria vs Roma -> Roma won
# prediciton was wrong
# Sampdoria: [25.18 -> 25.0] & [0.29 -> 0.25]
# Roma: [25.06 -> 25.37] & [0.46 -> 0.36]
# 79.74%---------------------------------------------
# Fiorentina vs Frosinone -> Frosinone won
# prediciton was wrong
# Fiorentina: [24.73 -> 24.14] & [0.59 -> 0.44]
# Frosinone: [23.46 -> 23.89] & [0.42 -> 0.34]
# 80.0%---------------------------------------------
# Udinese vs Empoli -> Udinese won
# prediciton was wrong
# Udinese: [24.55 -> 24.96] & [0.61 -> 0.52]
# Empoli: [24.92 -> 24.58] & [0.54 -> 0.45]
# 80.26%---------------------------------------------
# Cagliari vs Spal -> Cagliari won
# prediciton was wrong
# Cagliari: [24.42 -> 24.76] & [0.34 -> 0.27]
# Spal: [25.04 -> 24.71] & [0.35 -> 0.27]
# 80.53%---------------------------------------------
# Draw
# 80.79%---------------------------------------------
# Draw
# 81.05%---------------------------------------------
# Draw
# 81.32%---------------------------------------------
# Bologna vs Chievo -> Bologna won
# prediction was correct
# Bologna: [24.47 -> 24.49] & [0.35 -> 0.34]
# Chievo: [20.82 -> 20.8] & [1.13 -> 1.09]
# 81.58%---------------------------------------------
# Spal vs Juventus -> Spal won
# prediciton was wrong
# Spal: [24.71 -> 25.21] & [0.27 -> 0.25]
# Juventus: [28.31 -> 26.74] & [0.87 -> 0.6]
# 81.84%---------------------------------------------
# Roma vs Udinese -> Roma won
# prediction was correct
# Roma: [25.37 -> 25.52] & [0.36 -> 0.31]
# Udinese: [24.96 -> 24.71] & [0.52 -> 0.42]
# 82.11%---------------------------------------------
# Milan vs Lazio -> Milan won
# prediction was correct
# Milan: [25.66 -> 25.92] & [0.47 -> 0.38]
# Lazio: [25.61 -> 25.4] & [0.35 -> 0.29]
# 82.37%---------------------------------------------
# Draw
# 82.63%---------------------------------------------
# Draw
# 82.89%---------------------------------------------
# Sampdoria vs Genoa -> Sampdoria won
# prediction was correct
# Sampdoria: [25.0 -> 25.17] & [0.25 -> 0.23]
# Genoa: [24.79 -> 24.57] & [0.37 -> 0.3]
# 83.16%---------------------------------------------
# Draw
# 83.42%---------------------------------------------
# Chievo vs Napoli -> Napoli won
# prediction was correct
# Chievo: [20.8 -> 20.8] & [1.09 -> 1.07]
# Napoli: [26.75 -> 26.79] & [0.62 -> 0.56]
# 83.68%---------------------------------------------
# Frosinone vs Inter -> Inter won
# prediction was correct
# Frosinone: [23.89 -> 23.88] & [0.34 -> 0.3]
# Inter: [25.77 -> 25.77] & [0.3 -> 0.29]
# 83.95%---------------------------------------------
# Draw
# 84.21%---------------------------------------------
# Lazio vs Udinese -> Lazio won
# prediction was correct
# Lazio: [25.4 -> 25.48] & [0.29 -> 0.25]
# Udinese: [24.71 -> 24.55] & [0.42 -> 0.36]
# 84.47%---------------------------------------------
# Draw
# 84.74%---------------------------------------------
# Draw
# 85.0%---------------------------------------------
# Lazio vs Chievo -> Chievo won
# prediciton was wrong
# Lazio: [25.48 -> 25.0] & [0.25 -> 0.22]
# Chievo: [20.8 -> 22.88] & [1.07 -> 0.62]
# 85.26%---------------------------------------------
# Genoa vs Torino -> Torino won
# prediction was correct
# Genoa: [24.57 -> 24.53] & [0.3 -> 0.29]
# Torino: [25.94 -> 26.05] & [0.53 -> 0.47]
# 85.53%---------------------------------------------
# Empoli vs Spal -> Spal won
# prediction was correct
# Empoli: [24.58 -> 24.39] & [0.45 -> 0.37]
# Spal: [25.21 -> 25.3] & [0.25 -> 0.23]
# 85.79%---------------------------------------------
# Cagliari vs Frosinone -> Cagliari won
# prediction was correct
# Cagliari: [24.76 -> 24.87] & [0.27 -> 0.26]
# Frosinone: [23.88 -> 23.78] & [0.3 -> 0.26]
# 86.05%---------------------------------------------
# Bologna vs Sampdoria -> Bologna won
# prediciton was wrong
# Bologna: [24.49 -> 24.9] & [0.34 -> 0.27]
# Sampdoria: [25.17 -> 24.92] & [0.23 -> 0.2]
# 86.32%---------------------------------------------
# Juventus vs Fiorentina -> Juventus won
# prediction was correct
# Juventus: [26.74 -> 26.76] & [0.6 -> 0.54]
# Fiorentina: [24.14 -> 24.1] & [0.44 -> 0.39]
# 86.58%---------------------------------------------
# Draw
# 86.84%---------------------------------------------
# Napoli vs Atalanta -> Atalanta won
# prediciton was wrong
# Napoli: [26.79 -> 26.29] & [0.56 -> 0.43]
# Atalanta: [26.07 -> 26.34] & [0.32 -> 0.29]
# 87.11%---------------------------------------------
# Bologna vs Empoli -> Bologna won
# prediction was correct
# Bologna: [24.9 -> 25.02] & [0.27 -> 0.23]
# Empoli: [24.39 -> 24.24] & [0.37 -> 0.32]
# 87.37%---------------------------------------------
# Roma vs Cagliari -> Roma won
# prediction was correct
# Roma: [25.52 -> 25.64] & [0.31 -> 0.28]
# Cagliari: [24.87 -> 24.76] & [0.26 -> 0.23]
# 87.63%---------------------------------------------
# Draw
# 87.89%---------------------------------------------
# Frosinone vs Napoli -> Napoli won
# prediction was correct
# Frosinone: [23.78 -> 23.76] & [0.26 -> 0.25]
# Napoli: [26.29 -> 26.28] & [0.43 -> 0.41]
# 88.16%---------------------------------------------
# Draw
# 88.42%---------------------------------------------
# Draw
# 88.68%---------------------------------------------
# Sampdoria vs Lazio -> Lazio won
# prediction was correct
# Sampdoria: [24.92 -> 24.78] & [0.2 -> 0.18]
# Lazio: [25.0 -> 25.18] & [0.22 -> 0.19]
# 88.95%---------------------------------------------
# Torino vs Milan -> Torino won
# prediction was correct
# Torino: [26.05 -> 26.29] & [0.47 -> 0.41]
# Milan: [25.92 -> 25.69] & [0.38 -> 0.33]
# 89.21%---------------------------------------------
# Atalanta vs Udinese -> Atalanta won
# prediction was correct
# Atalanta: [26.34 -> 26.34] & [0.29 -> 0.28]
# Udinese: [24.55 -> 24.52] & [0.36 -> 0.36]
# 89.47%---------------------------------------------
# Fiorentina vs Sassuolo -> Sassuolo won
# prediciton was wrong
# Fiorentina: [24.1 -> 23.77] & [0.39 -> 0.32]
# Sassuolo: [23.42 -> 23.87] & [0.5 -> 0.4]
# 89.74%---------------------------------------------
# Draw
# 90.0%---------------------------------------------
# Chievo vs Spal -> Spal won
# prediction was correct
# Chievo: [22.88 -> 22.84] & [0.62 -> 0.57]
# Spal: [25.3 -> 25.31] & [0.23 -> 0.21]
# 90.26%---------------------------------------------
# Draw
# 90.53%---------------------------------------------
# Empoli vs Fiorentina -> Empoli won
# prediction was correct
# Empoli: [24.24 -> 24.4] & [0.32 -> 0.29]
# Fiorentina: [23.77 -> 23.59] & [0.32 -> 0.26]
# 90.79%---------------------------------------------
# Draw
# 91.05%---------------------------------------------
# Draw
# 91.32%---------------------------------------------
# Lazio vs Atalanta -> Atalanta won
# prediction was correct
# Lazio: [25.18 -> 25.14] & [0.19 -> 0.17]
# Atalanta: [26.34 -> 26.38] & [0.28 -> 0.25]
# 91.58%---------------------------------------------
# Draw
# 91.84%---------------------------------------------
# Napoli vs Cagliari -> Napoli won
# prediction was correct
# Napoli: [26.28 -> 26.32] & [0.41 -> 0.39]
# Cagliari: [24.76 -> 24.72] & [0.23 -> 0.23]
# 92.11%---------------------------------------------
# Milan vs Bologna -> Milan won
# prediction was correct
# Milan: [25.69 -> 25.83] & [0.33 -> 0.28]
# Bologna: [25.02 -> 24.94] & [0.23 -> 0.22]
# 92.37%---------------------------------------------
# Atalanta vs Genoa -> Atalanta won
# prediction was correct
# Atalanta: [26.38 -> 26.42] & [0.25 -> 0.24]
# Genoa: [24.53 -> 24.49] & [0.29 -> 0.27]
# 92.63%---------------------------------------------
# Cagliari vs Lazio -> Lazio won
# prediction was correct
# Cagliari: [24.72 -> 24.6] & [0.23 -> 0.2]
# Lazio: [25.14 -> 25.23] & [0.17 -> 0.15]
# 92.89%---------------------------------------------
# Fiorentina vs Milan -> Milan won
# prediction was correct
# Fiorentina: [23.59 -> 23.57] & [0.26 -> 0.25]
# Milan: [25.83 -> 25.84] & [0.28 -> 0.27]
# 93.16%---------------------------------------------
# Torino vs Sassuolo -> Torino won
# prediction was correct
# Torino: [26.29 -> 26.27] & [0.41 -> 0.41]
# Sassuolo: [23.87 -> 23.85] & [0.4 -> 0.37]
# 93.42%---------------------------------------------
# Sampdoria vs Empoli -> Empoli won
# prediciton was wrong
# Sampdoria: [24.78 -> 24.58] & [0.18 -> 0.15]
# Empoli: [24.4 -> 24.71] & [0.29 -> 0.23]
# 93.68%---------------------------------------------
# Frosinone vs Udinese -> Udinese won
# prediction was correct
# Frosinone: [23.76 -> 23.65] & [0.25 -> 0.22]
# Udinese: [24.52 -> 24.66] & [0.36 -> 0.31]
# 93.95%---------------------------------------------
# Spal vs Napoli -> Napoli won
# prediction was correct
# Spal: [25.31 -> 25.24] & [0.21 -> 0.2]
# Napoli: [26.32 -> 26.44] & [0.39 -> 0.34]
# 94.21%---------------------------------------------
# Roma vs Juventus -> Roma won
# prediciton was wrong
# Roma: [25.64 -> 25.95] & [0.28 -> 0.24]
# Juventus: [26.76 -> 26.17] & [0.54 -> 0.42]
# 94.47%---------------------------------------------
# Bologna vs Parma -> Bologna won
# prediction was correct
# Bologna: [24.94 -> 24.99] & [0.22 -> 0.19]
# Parma: [23.95 -> 23.86] & [0.29 -> 0.24]
# 94.74%---------------------------------------------
# Inter vs Chievo -> Inter won
# prediction was correct
# Inter: [25.77 -> 25.78] & [0.29 -> 0.29]
# Chievo: [22.84 -> 22.85] & [0.57 -> 0.58]
# 95.0%---------------------------------------------
# Udinese vs Spal -> Udinese won
# prediciton was wrong
# Udinese: [24.66 -> 25.02] & [0.31 -> 0.22]
# Spal: [25.24 -> 25.0] & [0.2 -> 0.18]
# 95.26%---------------------------------------------
# Draw
# 95.53%---------------------------------------------
# Draw
# 95.79%---------------------------------------------
# Draw
# 96.05%---------------------------------------------
# Parma vs Fiorentina -> Parma won
# prediction was correct
# Parma: [23.86 -> 23.99] & [0.24 -> 0.21]
# Fiorentina: [23.57 -> 23.4] & [0.25 -> 0.2]
# 96.32%---------------------------------------------
# Empoli vs Torino -> Empoli won
# prediciton was wrong
# Empoli: [24.71 -> 25.09] & [0.23 -> 0.19]
# Torino: [26.27 -> 25.61] & [0.41 -> 0.31]
# 96.58%---------------------------------------------
# Milan vs Frosinone -> Milan won
# prediction was correct
# Milan: [25.84 -> 25.88] & [0.27 -> 0.26]
# Frosinone: [23.65 -> 23.64] & [0.22 -> 0.22]
# 96.84%---------------------------------------------
# Napoli vs Inter -> Napoli won
# prediction was correct
# Napoli: [26.44 -> 26.57] & [0.34 -> 0.3]
# Inter: [25.78 -> 25.66] & [0.29 -> 0.26]
# 97.11%---------------------------------------------
# Draw
# 97.37%---------------------------------------------
# Draw
# 97.63%---------------------------------------------
# Draw
# 97.89%---------------------------------------------
# Bologna vs Napoli -> Bologna won
# prediciton was wrong
# Bologna: [24.99 -> 25.38] & [0.19 -> 0.16]
# Napoli: [26.57 -> 25.95] & [0.3 -> 0.22]
# 98.16%---------------------------------------------
# Torino vs Lazio -> Torino won
# prediction was correct
# Torino: [25.61 -> 25.81] & [0.31 -> 0.25]
# Lazio: [25.23 -> 25.13] & [0.15 -> 0.14]
# 98.42%---------------------------------------------
# Sampdoria vs Juventus -> Sampdoria won
# prediciton was wrong
# Sampdoria: [24.58 -> 24.85] & [0.15 -> 0.13]
# Juventus: [26.17 -> 25.42] & [0.42 -> 0.29]
# 98.68%---------------------------------------------
# Spal vs Milan -> Milan won
# prediction was correct
# Spal: [25.0 -> 24.92] & [0.18 -> 0.16]
# Milan: [25.88 -> 25.98] & [0.26 -> 0.24]
# 98.95%---------------------------------------------
# Roma vs Parma -> Roma won
# prediction was correct
# Roma: [25.95 -> 25.95] & [0.24 -> 0.23]
# Parma: [23.99 -> 24.0] & [0.21 -> 0.2]
# 99.21%---------------------------------------------
# Inter vs Empoli -> Inter won
# prediction was correct
# Inter: [25.66 -> 25.77] & [0.26 -> 0.21]
# Empoli: [25.09 -> 24.99] & [0.19 -> 0.17]
# 99.47%---------------------------------------------
# Draw
# 99.74%---------------------------------------------
# Cagliari vs Udinese -> Udinese won
# prediction was correct
# Cagliari: [24.6 -> 24.49] & [0.2 -> 0.17]
# Udinese: [25.02 -> 25.16] & [0.22 -> 0.19]
# 100.0%---------------------------------------------
# Atalanta vs Sassuolo -> Atalanta won
# prediction was correct
# Atalanta: [26.42 -> 26.4] & [0.24 -> 0.23]
# Sassuolo: [23.85 -> 23.82] & [0.37 -> 0.35]

# %%
r = n_cor / n_tot

print(r)
# Out:
# 0.6654411764705882

# %%
testmean = 25
testvar = 25/3

samps = []

for i in range(1000):
    samps.append(np.random.normal(testmean, np.sqrt(testvar)))


print(np.mean(samps), np.var(samps))
# Out:
# 25.16735134734648 8.603343153422891
